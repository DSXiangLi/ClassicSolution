# %%
import warnings
warnings.filterwarnings(action='ignore')

import pandas as pd 
import numpy as np 
import collections 
from itertools import chain
import torch 
import gensim
import time 
from sklearn.model_selection import KFold
from torch.utils.data.dataset import Dataset
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data.sampler import SequentialSampler, RandomSampler
from torch.utils.data.dataloader import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torch.nn import CrossEntropyLoss
from sklearn.model_selection import train_test_split
from gensim.models.phrases import Phrases
from gensim.models import Word2Vec

from src.train_utils import set_seed, ModelSave, get_torch_device, EarlyStop, TrainParams
from src.evaluation import multi_cls_report, classification_inference
from src.metric import  multi_cls_metrics,multi_cls_log
from src.dataset.tokenizer import GensimTokenizer
from src.enhancement.adversarial import FGM

from iflytek_app.dataset import MixDataset
from iflytek_app.process import train_process, test_process, result_process,kfold_inference
from iflytek_app.models import Textcnn
device = get_torch_device()
set_seed()
# Out:
# No GPU available, using the CPU instead.

# %%
c2v = GensimTokenizer( Word2Vec.load('./checkpoint/char_min1_win5_sg_d100'))
w2v = GensimTokenizer(Word2Vec.load('./checkpoint/phrase_min1_win5_sg_d100'))
w2v.init_vocab()
c2v.init_vocab()
phraser = Phrases.load('./checkpoint/phrase_tokenizer')
df, label2idx = train_process()
# Out:
#                 id           l1           l2          len
# count  4199.000000  4199.000000  4199.000000  4199.000000
# mean   2099.000000     8.969278    37.087878    46.057156
# std    1212.291219     4.576621    79.204914    79.332999
# min       0.000000     2.000000     1.000000     4.000000
# 25%    1049.500000     5.000000     6.000000    15.000000
# 50%    2099.000000     8.000000    12.000000    22.000000
# 75%    3148.500000    12.000000    26.000000    36.000000
# max    4198.000000    32.000000   946.000000   961.000000
# {'14784131 14858934 14784131 14845064': 0, '14852788 14717848 15639958 15632020': 1, '14844856 14724258 14925237 14854807': 2, '14925756 15639967 14853254 14728639': 3, '14844593 14924945': 4, '15709098 14716590 14924703 14779559': 5, '14726332 14728344 14854542 14844591': 6, '14858934 15636660 15704193 14849963': 7, '15710359 14847407 14845602 14859696': 8, '14794687 14782344': 9, '15630486 15702410 14718849 15709093': 10, '15632285 15706536 14721977 14925219': 11, '14782903 15634620 15638402 15706300': 12, '14844093 15705739 14854331 15699885': 13, '14856354 14844592': 14, '14847385 14844587 14848641 14847398': 15, '14783134 15697333 14854817 14925479': 16, '14924216 14781104 14717848 14791612': 17, '14786237 15697082 14722731 14924977': 18}

# %%
log_steps = 10
save_steps = 20
kfold = 5
tp = TrainParams(
    epoch_size=30,
    lr=1e-3,
    loss_fn=nn.CrossEntropyLoss(),
    max_seq_len=1000,
    batch_size=64,
    dropout_rate=0.5,
    label_size = len(label2idx),
    vocab_size = w2v.vocab_size,
    embedding_dim = w2v.embedding_size + c2v.embedding_size,
    embedding1=c2v.embedding, 
    embedding2 =w2v.embedding,
    num_train_steps=int(df.shape[0]/kfold * (kfold-1)), 
    filter_size=70,
    kernel_size_list = [2,3,4,5],
    hidden_size = 100,
    early_stop_params = {
        'monitor':'f1_micro',
        'mode':'max',
        'min_delta': 0,
        'patience':3,
        'verbose':False
    },
    scheduler_params={'mode': 'max',
                     'factor': 0.3,
                     'patience': 1,
                     'verbose': True,
                     'threshold':0.0001,
                     'threshold_mode':'rel',
                     'cooldown':0,
                     'min_lr':1e-6},
    epsilon=0.5,
    embedding_name='embedding'
)

# %%
kf = KFold(n_splits=kfold, shuffle=True, random_state=24)
for fold,(train_index, valid_index) in enumerate(kf.split(df)):
    train, valid = df.iloc[train_index], df.iloc[valid_index]

    train_dataset = MixDataset(tp.max_seq_len, w2v, c2v, phraser, label2idx, 
                               train['name'].values, train['description'].values, train['label'].values)
    valid_dataset = MixDataset(tp.max_seq_len, w2v, c2v, phraser, label2idx, 
                               valid['name'].values, valid['description'].values, valid['label'].values)
    train_sampler = RandomSampler(train_dataset)
    valid_sampler = SequentialSampler(valid_dataset)
    train_loader = DataLoader(train_dataset, sampler=train_sampler, batch_size=tp.batch_size)
    valid_loader = DataLoader(valid_dataset, sampler=valid_sampler, batch_size=tp.batch_size)
    
    CKPT = './checkpoint/textcnn_fgm/k{}'.format(fold)
    saver = ModelSave(CKPT, continue_train=False)
    saver.init()
    tb = SummaryWriter(CKPT)
    es = EarlyStop(**tp.early_stop_params)
    global_step = 0

    model = Textcnn(tp)
    fgm = FGM(model,tp.epsilon, tp.embedding_name)
    optimizer, scheduler = model.get_optimizer() 
    
    for epoch_i in range(tp['epoch_size']):
        if global_step==1:
            print(model)
        print(f"{'Epoch':^7} | {'Batch':^7} | {'Train Loss':^12} | {'Val Loss':^10}  | {'Elapsed':^9}")
        print("-"*60)

        # Measure the elapsed time of each epoch
        t0_epoch, t0_batch = time.time(), time.time()
        total_loss, batch_loss, batch_counts = 0, 0, 0

        model.train()
        for step, batch in enumerate(train_loader):
            global_step +=1
            batch_counts +=1

            #Forward propogate
            model.zero_grad()
            feature = {k:v.to(device) for k, v in batch.items()}
            logits = model(feature)
            loss = model.compute_loss(feature, logits)
            loss.backward()
            
            # attack
            fgm.attack() 
            logits = model(feature)
            loss = model.compute_loss(feature, logits)
            loss.backward()
            fgm.restore() 
            # step 
            batch_loss += loss.item()
            total_loss += loss.item()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            optimizer.step()

            # Log steps for train loss logging
            if (step % log_steps == 0 and step != 0) or (step == len(train_loader) - 1):
                time_elapsed = time.time() - t0_batch
                print(f"{epoch_i + 1:^7} | {step:^7} | {batch_loss / batch_counts:^12.6f} | {'-':^9} | {time_elapsed:^9.2f}")
                tb.add_scalar('loss/batch_train', batch_loss / batch_counts, global_step=global_step)
                batch_loss, batch_counts = 0, 0
                t0_batch = time.time()

            # Save steps for ckpt saving and dev evaluation
            if (step % save_steps == 0 and step != 0) or (step == len(train_loader) - 1):
                val_metrics = multi_cls_metrics(model, valid_loader, device)
                for key, val in val_metrics.items():
                    tb.add_scalar(f'metric/{key}', val, global_step=global_step)
                avg_train_loss = total_loss / step
                tb.add_scalars('loss/train_valid',{'train': avg_train_loss,
                                                    'valid': val_metrics['val_loss']}, global_step=global_step)
                saver(total_loss / step, val_metrics['val_loss'], epoch_i, global_step, model, optimizer, scheduler)

        # On Epoch End: calcualte train & valid loss and log overall metrics
        time_elapsed = time.time() - t0_epoch
        val_metrics = multi_cls_metrics(model, valid_loader, device)
        avg_train_loss = total_loss / step
        scheduler.step(val_metrics['f1_micro'])
        print("-"*70)
        print(f"{epoch_i + 1:^7} | {'-':^7} | {avg_train_loss:^12.6f} | {val_metrics['val_loss']:^10.6f} | {time_elapsed:^9.2f}")
        multi_cls_log(epoch_i, val_metrics)
        print("\n")
        if es.check(val_metrics):
            break
# Out:
# ./checkpoint/textcnn_fgm/k0 model cleaned
# Attack parameters ['embedding1.weight', 'embedding2.weight']
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    1    |   10    |   4.602240   |     -     |   17.36
#    1    |   20    |   2.793466   |     -     |   16.31
#    1    |   30    |   2.365093   |     -     |   17.44
#    1    |   40    |   2.060813   |     -     |   13.85
#    1    |   50    |   1.860926   |     -     |   16.99
#    1    |   52    |   1.858243   |     -     |   2.49
# ----------------------------------------------------------------------
#    1    |    -    |   2.791233   |  1.700344  |   88.05
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    1    |  24.364%  |  78.701%  |  35.891%  |     26.954%     |   24.364%    |  46.071%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    1    |  46.071%  |     -     |     -     |     46.071%     |   46.071%    |  46.071%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    2    |   10    |   2.609068   |     -     |   16.70
#    2    |   20    |   1.959650   |     -     |   14.20
#    2    |   30    |   1.579355   |     -     |   17.10
#    2    |   40    |   1.404940   |     -     |   13.92
#    2    |   50    |   1.500871   |     -     |   17.16
#    2    |   52    |   1.516340   |     -     |   2.08
# ----------------------------------------------------------------------
#    2    |    -    |   1.849627   |  1.335498  |   84.29
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    2    |  37.237%  |  85.285%  |  46.930%  |     43.513%     |   37.237%    |  57.500%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    2    |  57.500%  |     -     |     -     |     57.500%     |   57.500%    |  57.500%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    3    |   10    |   1.802429   |     -     |   15.64
#    3    |   20    |   1.566714   |     -     |   14.13
#    3    |   30    |   1.171462   |     -     |   17.06
#    3    |   40    |   1.188747   |     -     |   13.90
#    3    |   50    |   1.087819   |     -     |   17.08
#    3    |   52    |   1.140403   |     -     |   2.10
# ----------------------------------------------------------------------
#    3    |    -    |   1.389518   |  1.216107  |   83.34
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    3    |  46.564%  |  87.163%  |  53.630%  |     53.384%     |   46.564%    |  63.690%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    3    |  63.690%  |     -     |     -     |     63.690%     |   63.690%    |  63.690%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    4    |   10    |   1.425962   |     -     |   16.97
#    4    |   20    |   1.214390   |     -     |   16.41
#    4    |   30    |   1.037811   |     -     |   30.07
#    4    |   40    |   0.972325   |     -     |   26.93
#    4    |   50    |   0.859841   |     -     |   34.42
#    4    |   52    |   1.027667   |     -     |   4.30
# ----------------------------------------------------------------------
#    4    |    -    |   1.126627   |  1.138277  |  135.49
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    4    |  48.698%  |  88.171%  |  55.770%  |     56.259%     |   48.698%    |  65.952%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    4    |  65.952%  |     -     |     -     |     65.952%     |   65.952%    |  65.952%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    5    |   10    |   1.207611   |     -     |   31.62
#    5    |   20    |   1.016250   |     -     |   19.49
#    5    |   30    |   0.740315   |     -     |   21.31
#    5    |   40    |   0.817540   |     -     |   17.19
#    5    |   50    |   0.765321   |     -     |   31.65
#    5    |   52    |   0.780833   |     -     |   3.72
# ----------------------------------------------------------------------
#    5    |    -    |   0.927685   |  1.095309  |  130.90
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    5    |  52.358%  |  88.978%  |  59.816%  |     62.292%     |   52.358%    |  69.524%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    5    |  69.524%  |     -     |     -     |     69.524%     |   69.524%    |  69.524%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    6    |   10    |   1.086184   |     -     |   28.84
#    6    |   20    |   0.999216   |     -     |   25.89
#    6    |   30    |   0.689309   |     -     |   31.07
#    6    |   40    |   0.649631   |     -     |   25.58
#    6    |   50    |   0.569679   |     -     |   32.28
#    6    |   52    |   0.600618   |     -     |   3.99
# ----------------------------------------------------------------------
#    6    |    -    |   0.812069   |  1.089597  |  153.53
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    6    |  56.780%  |  89.220%  |  61.814%  |     61.920%     |   56.780%    |  70.595%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    6    |  70.595%  |     -     |     -     |     70.595%     |   70.595%    |  70.595%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    7    |   10    |   0.863397   |     -     |   28.59
#    7    |   20    |   0.815059   |     -     |   26.14
#    7    |   30    |   0.457434   |     -     |   32.41
#    7    |   40    |   0.541804   |     -     |   25.65
#    7    |   50    |   0.504111   |     -     |   34.85
#    7    |   52    |   0.441788   |     -     |   4.30
# ----------------------------------------------------------------------
#    7    |    -    |   0.645481   |  1.084388  |  158.82
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    7    |  54.727%  |  88.803%  |  61.360%  |     67.410%     |   54.727%    |  70.714%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    7    |  70.714%  |     -     |     -     |     70.714%     |   70.714%    |  70.714%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    8    |   10    |   0.788131   |     -     |   31.46
#    8    |   20    |   0.702485   |     -     |   27.46
#    8    |   30    |   0.386362   |     -     |   32.50
#    8    |   40    |   0.400435   |     -     |   27.08
#    8    |   50    |   0.339015   |     -     |   33.83
#    8    |   52    |   0.286082   |     -     |   4.19
# ----------------------------------------------------------------------
#    8    |    -    |   0.529319   |  1.123520  |  162.97
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    8    |  55.736%  |  89.261%  |  61.900%  |     67.207%     |   55.736%    |  71.071%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    8    |  71.071%  |     -     |     -     |     71.071%     |   71.071%    |  71.071%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    9    |   10    |   0.688477   |     -     |   29.92
#    9    |   20    |   0.590918   |     -     |   27.62
#    9    |   30    |   0.328212   |     -     |   34.70
#    9    |   40    |   0.287910   |     -     |   28.25
#    9    |   50    |   0.298474   |     -     |   42.48
#    9    |   52    |   0.444302   |     -     |   7.16
# ----------------------------------------------------------------------
#    9    |    -    |   0.452250   |  1.170179  |  178.19
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    9    |  56.254%  |  89.651%  |  62.288%  |     66.164%     |   56.254%    |  70.476%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    9    |  70.476%  |     -     |     -     |     70.476%     |   70.476%    |  70.476%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   10    |   10    |   0.595129   |     -     |   34.35
#   10    |   20    |   0.555503   |     -     |   27.03
#   10    |   30    |   0.226328   |     -     |   35.09
#   10    |   40    |   0.243703   |     -     |   27.63
#   10    |   50    |   0.259436   |     -     |   33.58
#   10    |   52    |   0.394784   |     -     |   3.92
# Epoch    10: reducing learning rate of group 0 to 3.0000e-04.
# ----------------------------------------------------------------------
#   10    |    -    |   0.388186   |  1.172520  |  167.52
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   10    |  55.597%  |  89.152%  |  62.627%  |     64.573%     |   55.597%    |  69.643%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   10    |  69.643%  |     -     |     -     |     69.643%     |   69.643%    |  69.643%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   11    |   10    |   0.549683   |     -     |   30.88
#   11    |   20    |   0.377150   |     -     |   29.51
#   11    |   30    |   0.155932   |     -     |   36.43
#   11    |   40    |   0.148128   |     -     |   27.14
#   11    |   50    |   0.109872   |     -     |   34.27
#   11    |   52    |   0.142803   |     -     |   3.94
# ----------------------------------------------------------------------
#   11    |    -    |   0.273903   |  1.129136  |  168.75
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   11    |  56.699%  |  89.766%  |  62.400%  |     69.491%     |   56.699%    |  73.333%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   11    |  73.333%  |     -     |     -     |     73.333%     |   73.333%    |  73.333%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   12    |   10    |   0.257466   |     -     |   31.20
#   12    |   20    |   0.346046   |     -     |   26.90
#   12    |   30    |   0.147403   |     -     |   35.20
#   12    |   40    |   0.096176   |     -     |   29.63
#   12    |   50    |   0.113293   |     -     |   38.80
#   12    |   52    |   0.141478   |     -     |   5.03
# ----------------------------------------------------------------------
#   12    |    -    |   0.195082   |  1.134437  |  173.34
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   12    |  56.392%  |  89.871%  |  63.317%  |     69.518%     |   56.392%    |  73.333%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   12    |  73.333%  |     -     |     -     |     73.333%     |   73.333%    |  73.333%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   13    |   10    |   0.282063   |     -     |   34.13
#   13    |   20    |   0.282349   |     -     |   30.48
#   13    |   30    |   0.116226   |     -     |   34.81
#   13    |   40    |   0.107948   |     -     |   27.59
#   13    |   50    |   0.107119   |     -     |   34.32
#   13    |   52    |   0.100391   |     -     |   4.96
# ----------------------------------------------------------------------
#   13    |    -    |   0.181536   |  1.149033  |  173.11
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   13    |  57.589%  |  89.772%  |  62.402%  |     68.710%     |   57.589%    |  73.571%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   13    |  73.571%  |     -     |     -     |     73.571%     |   73.571%    |  73.571%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   14    |   10    |   0.277515   |     -     |   36.17
#   14    |   20    |   0.257604   |     -     |   28.18
#   14    |   30    |   0.084952   |     -     |   35.17
#   14    |   40    |   0.090157   |     -     |   29.86
#   14    |   50    |   0.091758   |     -     |   36.59
#   14    |   52    |   0.120825   |     -     |   4.06
# ----------------------------------------------------------------------
#   14    |    -    |   0.164212   |  1.177948  |  176.33
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   14    |  57.537%  |  89.738%  |  62.679%  |     69.255%     |   57.537%    |  73.810%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   14    |  73.810%  |     -     |     -     |     73.810%     |   73.810%    |  73.810%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   15    |   10    |   0.251476   |     -     |   34.31
#   15    |   20    |   0.309403   |     -     |   27.96
#   15    |   30    |   0.096095   |     -     |   35.70
#   15    |   40    |   0.082126   |     -     |   28.00
#   15    |   50    |   0.079657   |     -     |   33.22
#   15    |   52    |   0.063155   |     -     |   3.73
# ----------------------------------------------------------------------
#   15    |    -    |   0.164718   |  1.210034  |  168.66
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   15    |  57.729%  |  89.602%  |  63.059%  |     66.684%     |   57.729%    |  73.333%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   15    |  73.333%  |     -     |     -     |     73.333%     |   73.333%    |  73.333%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   16    |   10    |   0.255542   |     -     |   28.72
#   16    |   20    |   0.256905   |     -     |   29.86
#   16    |   30    |   0.081255   |     -     |   36.92
#   16    |   40    |   0.090777   |     -     |   27.68
#   16    |   50    |   0.083388   |     -     |   34.34
#   16    |   52    |   0.107343   |     -     |   4.25
# Epoch    16: reducing learning rate of group 0 to 9.0000e-05.
# ----------------------------------------------------------------------
#   16    |    -    |   0.156709   |  1.166722  |  168.38
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   16    |  57.649%  |  89.745%  |  62.673%  |     67.886%     |   57.649%    |  73.810%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   16    |  73.810%  |     -     |     -     |     73.810%     |   73.810%    |  73.810%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   17    |   10    |   0.191657   |     -     |   31.25
#   17    |   20    |   0.207407   |     -     |   28.89
#   17    |   30    |   0.063030   |     -     |   33.37
#   17    |   40    |   0.057290   |     -     |   27.39
#   17    |   50    |   0.066824   |     -     |   21.63
#   17    |   52    |   0.063025   |     -     |   4.31
# ----------------------------------------------------------------------
#   17    |    -    |   0.118842   |  1.151023  |  153.42
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   17    |  56.922%  |  89.856%  |  62.604%  |     68.882%     |   56.922%    |  73.571%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   17    |  73.571%  |     -     |     -     |     73.571%     |   73.571%    |  73.571%
#
#
#
#
# ./checkpoint/textcnn_fgm/k1 model cleaned
# Attack parameters ['embedding1.weight', 'embedding2.weight']
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    1    |   10    |   4.164949   |     -     |   31.37
#    1    |   20    |   2.641634   |     -     |   28.78
#    1    |   30    |   2.353209   |     -     |   32.44
#    1    |   40    |   1.920630   |     -     |   27.75
#    1    |   50    |   1.791964   |     -     |   33.21
#    1    |   52    |   1.859169   |     -     |   4.38
# ----------------------------------------------------------------------
#    1    |    -    |   2.627060   |  1.566454  |  164.44
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    1    |  33.163%  |  75.974%  |  43.089%  |     40.270%     |   33.163%    |  51.667%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    1    |  51.667%  |     -     |     -     |     51.667%     |   51.667%    |  51.667%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    2    |   10    |   2.901402   |     -     |   28.90
#    2    |   20    |   2.053045   |     -     |   26.02
#    2    |   30    |   1.470443   |     -     |   33.12
#    2    |   40    |   1.417022   |     -     |   27.25
#    2    |   50    |   1.349901   |     -     |   33.07
#    2    |   52    |   1.292319   |     -     |   4.72
# ----------------------------------------------------------------------
#    2    |    -    |   1.873157   |  1.223908  |  161.05
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    2    |  43.475%  |  81.251%  |  54.422%  |     52.936%     |   43.475%    |  63.095%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    2    |  63.095%  |     -     |     -     |     63.095%     |   63.095%    |  63.095%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    3    |   10    |   1.513523   |     -     |   31.14
#    3    |   20    |   1.453111   |     -     |   28.81
#    3    |   30    |   1.142461   |     -     |   33.13
#    3    |   40    |   1.214684   |     -     |   28.90
#    3    |   50    |   1.120388   |     -     |   34.33
#    3    |   52    |   1.393417   |     -     |   4.00
# ----------------------------------------------------------------------
#    3    |    -    |   1.321962   |  1.071553  |  166.59
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    3    |  54.685%  |  82.864%  |  62.231%  |     61.017%     |   54.685%    |  68.095%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    3    |  68.095%  |     -     |     -     |     68.095%     |   68.095%    |  68.095%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    4    |   10    |   1.285409   |     -     |   32.52
#    4    |   20    |   1.283835   |     -     |   28.03
#    4    |   30    |   0.946331   |     -     |   32.47
#    4    |   40    |   0.913594   |     -     |   28.46
#    4    |   50    |   0.891833   |     -     |   34.71
#    4    |   52    |   1.046322   |     -     |   4.53
# ----------------------------------------------------------------------
#    4    |    -    |   1.088232   |  0.998091  |  167.01
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    4    |  57.123%  |  83.338%  |  65.356%  |     63.564%     |   57.123%    |  71.548%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    4    |  71.548%  |     -     |     -     |     71.548%     |   71.548%    |  71.548%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    5    |   10    |   1.188254   |     -     |   30.73
#    5    |   20    |   1.110112   |     -     |   28.62
#    5    |   30    |   0.727591   |     -     |   35.35
#    5    |   40    |   0.701415   |     -     |   28.60
#    5    |   50    |   0.725469   |     -     |   33.61
#    5    |   52    |   0.722812   |     -     |   4.72
# ----------------------------------------------------------------------
#    5    |    -    |   0.906967   |  1.006902  |  168.71
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    5    |  58.999%  |  83.675%  |  68.038%  |     63.274%     |   58.999%    |  71.071%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    5    |  71.071%  |     -     |     -     |     71.071%     |   71.071%    |  71.071%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    6    |   10    |   0.884851   |     -     |   33.88
#    6    |   20    |   0.857040   |     -     |   26.55
#    6    |   30    |   0.585018   |     -     |   32.16
#    6    |   40    |   0.582434   |     -     |   30.29
#    6    |   50    |   0.585669   |     -     |   38.28
#    6    |   52    |   0.849960   |     -     |   4.98
# ----------------------------------------------------------------------
#    6    |    -    |   0.721825   |  0.948471  |  172.43
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    6    |  62.844%  |  84.416%  |  69.154%  |     66.693%     |   62.844%    |  74.048%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    6    |  74.048%  |     -     |     -     |     74.048%     |   74.048%    |  74.048%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    7    |   10    |   0.847012   |     -     |   31.18
#    7    |   20    |   0.768654   |     -     |   26.22
#    7    |   30    |   0.469517   |     -     |   34.43
#    7    |   40    |   0.491454   |     -     |   26.91
#    7    |   50    |   0.493692   |     -     |   20.46
#    7    |   52    |   0.593803   |     -     |   2.52
# ----------------------------------------------------------------------
#    7    |    -    |   0.629575   |  0.947085  |  145.79
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    7    |  62.878%  |  83.094%  |  69.483%  |     68.753%     |   62.878%    |  74.524%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    7    |  74.524%  |     -     |     -     |     74.524%     |   74.524%    |  74.524%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    8    |   10    |   0.728759   |     -     |   23.87
#    8    |   20    |   0.643708   |     -     |   28.98
#    8    |   30    |   0.391348   |     -     |   31.92
#    8    |   40    |   0.382891   |     -     |   28.84
#    8    |   50    |   0.353856   |     -     |   35.46
#    8    |   52    |   0.446453   |     -     |   4.95
# ----------------------------------------------------------------------
#    8    |    -    |   0.512063   |  0.999869  |  160.88
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    8    |  64.819%  |  83.977%  |  69.311%  |     63.582%     |   64.819%    |  73.214%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    8    |  73.214%  |     -     |     -     |     73.214%     |   73.214%    |  73.214%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    9    |   10    |   0.603710   |     -     |   34.00
#    9    |   20    |   0.600046   |     -     |   31.00
#    9    |   30    |   0.291542   |     -     |   31.03
#    9    |   40    |   0.288851   |     -     |   22.84
#    9    |   50    |   0.317643   |     -     |   27.00
#    9    |   52    |   0.253219   |     -     |   3.36
# Epoch     9: reducing learning rate of group 0 to 3.0000e-04.
# ----------------------------------------------------------------------
#    9    |    -    |   0.425540   |  1.042767  |  154.45
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    9    |  63.307%  |  83.547%  |  69.904%  |     70.527%     |   63.307%    |  74.524%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    9    |  74.524%  |     -     |     -     |     74.524%     |   74.524%    |  74.524%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   10    |   10    |   0.506100   |     -     |   25.00
#   10    |   20    |   0.455952   |     -     |   22.95
#   10    |   30    |   0.165103   |     -     |   28.31
#   10    |   40    |   0.176814   |     -     |   22.44
#   10    |   50    |   0.174639   |     -     |   28.06
#   10    |   52    |   0.151411   |     -     |   3.33
# ----------------------------------------------------------------------
#   10    |    -    |   0.299904   |  0.930518  |  135.30
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   10    |  64.897%  |  83.874%  |  71.072%  |     71.476%     |   64.897%    |  77.143%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   10    |  77.143%  |     -     |     -     |     77.143%     |   77.143%    |  77.143%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   11    |   10    |   0.398423   |     -     |   24.86
#   11    |   20    |   0.313069   |     -     |   23.10
#   11    |   30    |   0.124290   |     -     |   28.47
#   11    |   40    |   0.137869   |     -     |   22.68
#   11    |   50    |   0.134844   |     -     |   27.95
#   11    |   52    |   0.172187   |     -     |   21.21
# ----------------------------------------------------------------------
#   11    |    -    |   0.227457   |  0.975686  |  155.64
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   11    |  64.294%  |  83.703%  |  70.220%  |     69.969%     |   64.294%    |  76.548%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   11    |  76.548%  |     -     |     -     |     76.548%     |   76.548%    |  76.548%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   12    |   10    |   0.366232   |     -     |   21.85
#   12    |   20    |   0.350537   |     -     |   20.19
#   12    |   30    |   0.123134   |     -     |   23.73
#   12    |   40    |   0.145151   |     -     |   20.24
#   12    |   50    |   0.127953   |     -     |   28.99
#   12    |   52    |   0.160143   |     -     |   3.35
# Epoch    12: reducing learning rate of group 0 to 9.0000e-05.
# ----------------------------------------------------------------------
#   12    |    -    |   0.227242   |  0.958798  |  123.68
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   12    |  63.786%  |  83.738%  |  70.116%  |     69.804%     |   63.786%    |  76.429%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   12    |  76.429%  |     -     |     -     |     76.429%     |   76.429%    |  76.429%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   13    |   10    |   0.309837   |     -     |   25.25
#   13    |   20    |   0.293759   |     -     |   23.79
#   13    |   30    |   0.117521   |     -     |   28.42
#   13    |   40    |   0.102485   |     -     |   22.78
#   13    |   50    |   0.087550   |     -     |   28.64
#   13    |   52    |   0.128400   |     -     |   3.42
# ----------------------------------------------------------------------
#   13    |    -    |   0.186118   |  0.958500  |  137.70
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   13    |  63.980%  |  83.609%  |  69.852%  |     71.925%     |   63.980%    |  77.143%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   13    |  77.143%  |     -     |     -     |     77.143%     |   77.143%    |  77.143%
#
#
#
#
# ./checkpoint/textcnn_fgm/k2 model cleaned
# Attack parameters ['embedding1.weight', 'embedding2.weight']
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    1    |   10    |   4.108874   |     -     |   25.36
#    1    |   20    |   2.543210   |     -     | 10908.48
#    1    |   30    |   2.331885   |     -     |  265.26
#    1    |   40    |   1.949992   |     -     |   21.84
#    1    |   50    |   1.768996   |     -     |   28.98
#    1    |   52    |   1.938592   |     -     |   3.60
# ----------------------------------------------------------------------
#    1    |    -    |   2.596454   |  1.776498  | 11258.98
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    1    |  29.014%  |  77.578%  |  37.443%  |     31.733%     |   29.014%    |  49.048%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    1    |  49.048%  |     -     |     -     |     49.048%     |   49.048%    |  49.048%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    2    |   10    |   2.849100   |     -     |   25.94
#    2    |   20    |   2.045768   |     -     |   23.39
#    2    |   30    |   1.543895   |     -     |   28.34
#    2    |   40    |   1.374334   |     -     |   22.75
#    2    |   50    |   1.390889   |     -     |   29.49
#    2    |   52    |   1.175091   |     -     |   3.60
# ----------------------------------------------------------------------
#    2    |    -    |   1.869984   |  1.374377  |  139.23
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    2    |  39.579%  |  84.424%  |  51.757%  |     47.377%     |   39.579%    |  62.024%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    2    |  62.024%  |     -     |     -     |     62.024%     |   62.024%    |  62.024%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    3    |   10    |   1.664827   |     -     |   25.62
#    3    |   20    |   1.487528   |     -     |   23.19
#    3    |   30    |   1.179897   |     -     |   28.60
#    3    |   40    |   1.163046   |     -     |   24.10
#    3    |   50    |   1.160454   |     -     |   28.75
#    3    |   52    |   1.325658   |     -     |   3.69
# ----------------------------------------------------------------------
#    3    |    -    |   1.362955   |  1.211376  |  139.48
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    3    |  44.798%  |  85.002%  |  58.019%  |     54.438%     |   44.798%    |  66.071%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    3    |  66.071%  |     -     |     -     |     66.071%     |   66.071%    |  66.071%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    4    |   10    |   1.297834   |     -     |   25.56
#    4    |   20    |   1.435436   |     -     |   23.61
#    4    |   30    |   1.001716   |     -     |   28.52
#    4    |   40    |   0.917232   |     -     |   22.70
#    4    |   50    |   0.918450   |     -     |   28.21
#    4    |   52    |   1.000516   |     -     |   3.45
# ----------------------------------------------------------------------
#    4    |    -    |   1.134722   |  1.115268  |  137.37
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    4    |  52.617%  |  85.542%  |  62.313%  |     65.385%     |   52.617%    |  70.357%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    4    |  70.357%  |     -     |     -     |     70.357%     |   70.357%    |  70.357%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    5    |   10    |   1.091672   |     -     |   25.42
#    5    |   20    |   1.147761   |     -     |   22.96
#    5    |   30    |   0.765615   |     -     |   28.65
#    5    |   40    |   0.733824   |     -     |   23.00
#    5    |   50    |   0.837670   |     -     |   28.31
#    5    |   52    |   0.908155   |     -     |   3.51
# ----------------------------------------------------------------------
#    5    |    -    |   0.936027   |  1.201397  |  137.21
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    5    |  47.021%  |  86.214%  |  61.698%  |     66.093%     |   47.021%    |  68.333%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    5    |  68.333%  |     -     |     -     |     68.333%     |   68.333%    |  68.333%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    6    |   10    |   1.037726   |     -     |   25.26
#    6    |   20    |   0.893817   |     -     |   23.06
#    6    |   30    |   0.581203   |     -     |   28.09
#    6    |   40    |   0.582034   |     -     |   22.88
#    6    |   50    |   0.618742   |     -     |   28.36
#    6    |   52    |   0.622189   |     -     |   3.43
# ----------------------------------------------------------------------
#    6    |    -    |   0.758026   |  1.110190  |  136.47
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    6    |  54.166%  |  86.990%  |  64.672%  |     71.906%     |   54.166%    |  71.429%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    6    |  71.429%  |     -     |     -     |     71.429%     |   71.429%    |  71.429%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    7    |   10    |   0.805317   |     -     |   25.64
#    7    |   20    |   0.768447   |     -     |   23.75
#    7    |   30    |   0.464354   |     -     |   28.08
#    7    |   40    |   0.485202   |     -     |   22.96
#    7    |   50    |   0.491613   |     -     |   29.94
#    7    |   52    |   0.407723   |     -     |   3.46
# ----------------------------------------------------------------------
#    7    |    -    |   0.610963   |  1.108050  |  139.22
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    7    |  54.565%  |  87.601%  |  66.162%  |     71.999%     |   54.565%    |  72.143%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    7    |  72.143%  |     -     |     -     |     72.143%     |   72.143%    |  72.143%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    8    |   10    |   0.619871   |     -     |   25.53
#    8    |   20    |   0.637821   |     -     |   22.91
#    8    |   30    |   0.320906   |     -     |   28.37
#    8    |   40    |   0.367047   |     -     |   22.85
#    8    |   50    |   0.382708   |     -     |   28.08
#    8    |   52    |   0.480745   |     -     |   3.48
# ----------------------------------------------------------------------
#    8    |    -    |   0.478171   |  1.072722  |  136.71
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    8    |  57.799%  |  87.437%  |  66.140%  |     68.008%     |   57.799%    |  73.333%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    8    |  73.333%  |     -     |     -     |     73.333%     |   73.333%    |  73.333%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    9    |   10    |   0.809418   |     -     |   25.40
#    9    |   20    |   0.599683   |     -     |   23.01
#    9    |   30    |   0.275293   |     -     |   27.77
#    9    |   40    |   0.263548   |     -     |   22.81
#    9    |   50    |   0.280407   |     -     |   27.69
#    9    |   52    |   0.355173   |     -     |   3.40
# ----------------------------------------------------------------------
#    9    |    -    |   0.457755   |  1.098683  |  135.16
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    9    |  57.312%  |  88.077%  |  67.395%  |     72.363%     |   57.312%    |  72.738%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    9    |  72.738%  |     -     |     -     |     72.738%     |   72.738%    |  72.738%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   10    |   10    |   0.633016   |     -     |   24.03
#   10    |   20    |   0.396386   |     -     |   21.75
#   10    |   30    |   0.261610   |     -     |   26.72
#   10    |   40    |   0.232174   |     -     |   21.66
#   10    |   50    |   0.233134   |     -     |   26.66
#   10    |   52    |   0.265792   |     -     |   3.27
# ----------------------------------------------------------------------
#   10    |    -    |   0.360150   |  1.074393  |  129.26
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   10    |  58.062%  |  88.146%  |  66.790%  |     69.891%     |   58.062%    |  74.048%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   10    |  74.048%  |     -     |     -     |     74.048%     |   74.048%    |  74.048%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   11    |   10    |   0.448368   |     -     |   24.13
#   11    |   20    |   0.417175   |     -     |   22.06
#   11    |   30    |   0.176654   |     -     |   26.60
#   11    |   40    |   0.209312   |     -     |   21.49
#   11    |   50    |   0.193429   |     -     |   26.64
#   11    |   52    |   0.171989   |     -     |   3.28
# ----------------------------------------------------------------------
#   11    |    -    |   0.293110   |  1.157158  |  129.32
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   11    |  57.001%  |  88.331%  |  66.580%  |     63.712%     |   57.001%    |  72.500%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   11    |  72.500%  |     -     |     -     |     72.500%     |   72.500%    |  72.500%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   12    |   10    |   0.437617   |     -     |   23.99
#   12    |   20    |   0.416412   |     -     |   22.68
#   12    |   30    |   0.159946   |     -     |   27.28
#   12    |   40    |   0.155272   |     -     |   22.39
#   12    |   50    |   0.151249   |     -     |   26.58
#   12    |   52    |   0.352150   |     -     |   3.27
# Epoch    12: reducing learning rate of group 0 to 3.0000e-04.
# ----------------------------------------------------------------------
#   12    |    -    |   0.275902   |  1.203137  |  131.24
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ...
# ------------------------------------------------------------
#    4    |   10    |   1.409957   |     -     |   22.21
#    4    |   20    |   1.153977   |     -     |   20.48
#    4    |   30    |   0.942480   |     -     |   25.16
#    4    |   40    |   1.001137   |     -     |   20.04
#    4    |   50    |   1.004435   |     -     |   24.65
#    4    |   52    |   0.965317   |     -     |   3.13
# ----------------------------------------------------------------------
#    4    |    -    |   1.124239   |  1.001813  |  120.41
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    4    |  50.292%  |  88.371%  |  57.954%  |     59.672%     |   50.292%    |  71.990%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    4    |  71.990%  |     -     |     -     |     71.990%     |   71.990%    |  71.990%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    5    |   10    |   1.132584   |     -     |   16.92
#    5    |   20    |   1.077217   |     -     |   18.65
#    5    |   30    |   0.783507   |     -     |   24.37
#    5    |   40    |   0.771312   |     -     |   20.22
#    5    |   50    |   0.767312   |     -     |   24.59
#    5    |   52    |   0.828923   |     -     |   3.07
# ----------------------------------------------------------------------
#    5    |    -    |   0.925187   |  0.968043  |  112.55
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    5    |  55.740%  |  88.708%  |  60.106%  |     60.642%     |   55.740%    |  74.374%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    5    |  74.374%  |     -     |     -     |     74.374%     |   74.374%    |  74.374%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    6    |   10    |   0.929840   |     -     |   22.29
#    6    |   20    |   0.919838   |     -     |   20.17
#    6    |   30    |   0.671793   |     -     |   24.78
#    6    |   40    |   0.608650   |     -     |   20.13
#    6    |   50    |   0.589464   |     -     |   24.71
#    6    |   52    |   0.622024   |     -     |   3.00
# ----------------------------------------------------------------------
#    6    |    -    |   0.757110   |  0.943121  |  119.78
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    6    |  56.266%  |  88.721%  |  61.588%  |     60.111%     |   56.266%    |  74.732%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    6    |  74.732%  |     -     |     -     |     74.732%     |   74.732%    |  74.732%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    7    |   10    |   0.840080   |     -     |   22.21
#    7    |   20    |   0.798833   |     -     |   19.96
#    7    |   30    |   0.532518   |     -     |   24.67
#    7    |   40    |   0.546969   |     -     |   20.24
#    7    |   50    |   0.436206   |     -     |   24.99
#    7    |   52    |   0.508687   |     -     |   3.07
# ----------------------------------------------------------------------
#    7    |    -    |   0.642375   |  0.973841  |  119.82
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    7    |  54.366%  |  88.669%  |  61.430%  |     55.850%     |   54.366%    |  73.063%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    7    |  73.063%  |     -     |     -     |     73.063%     |   73.063%    |  73.063%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    8    |   10    |   0.691887   |     -     |   22.30
#    8    |   20    |   0.650416   |     -     |   20.49
#    8    |   30    |   0.381459   |     -     |   24.84
#    8    |   40    |   0.353969   |     -     |   19.86
#    8    |   50    |   0.379205   |     -     |   24.98
#    8    |   52    |   0.524250   |     -     |   3.11
# ----------------------------------------------------------------------
#    8    |    -    |   0.505957   |  0.918984  |  120.26
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    8    |  55.637%  |  89.055%  |  62.153%  |     57.034%     |   55.637%    |  74.970%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    8    |  74.970%  |     -     |     -     |     74.970%     |   74.970%    |  74.970%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    9    |   10    |   0.580374   |     -     |   22.08
#    9    |   20    |   0.593536   |     -     |   20.43
#    9    |   30    |   0.281733   |     -     |   24.61
#    9    |   40    |   0.269652   |     -     |   20.05
#    9    |   50    |   0.318922   |     -     |   24.72
#    9    |   52    |   0.219709   |     -     |   3.09
# ----------------------------------------------------------------------
#    9    |    -    |   0.412730   |  1.001776  |  119.66
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    9    |  54.760%  |  89.367%  |  62.764%  |     63.037%     |   54.760%    |  73.421%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    9    |  73.421%  |     -     |     -     |     73.421%     |   73.421%    |  73.421%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   10    |   10    |   0.510873   |     -     |   22.85
#   10    |   20    |   0.570384   |     -     |   20.05
#   10    |   30    |   0.241746   |     -     |   24.81
#   10    |   40    |   0.268687   |     -     |   20.20
#   10    |   50    |   0.255257   |     -     |   24.92
#   10    |   52    |   0.210070   |     -     |   3.10
# ----------------------------------------------------------------------
#   10    |    -    |   0.373086   |  0.955842  |  120.61
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   10    |  55.515%  |  89.247%  |  61.988%  |     57.940%     |   55.515%    |  75.089%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   10    |  75.089%  |     -     |     -     |     75.089%     |   75.089%    |  75.089%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   11    |   10    |   0.427035   |     -     |   22.22
#   11    |   20    |   0.394496   |     -     |   20.33
#   11    |   30    |   0.210056   |     -     |   24.72
#   11    |   40    |   0.172291   |     -     |   20.20
#   11    |   50    |   0.191860   |     -     |   25.02
#   11    |   52    |   0.407352   |     -     |   3.14
# ----------------------------------------------------------------------
#   11    |    -    |   0.292291   |  1.045824  |  120.21
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   11    |  53.513%  |  88.629%  |  62.880%  |     61.855%     |   53.513%    |  73.302%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   11    |  73.302%  |     -     |     -     |     73.302%     |   73.302%    |  73.302%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   12    |   10    |   0.456651   |     -     |   22.64
#   12    |   20    |   0.415816   |     -     |   20.53
#   12    |   30    |   0.164055   |     -     |   24.92
#   12    |   40    |   0.164854   |     -     |   20.20
#   12    |   50    |   0.170078   |     -     |   24.68
#   12    |   52    |   0.174872   |     -     |   3.14
# Epoch    12: reducing learning rate of group 0 to 3.0000e-04.
# ----------------------------------------------------------------------
#   12    |    -    |   0.279249   |  1.016643  |  120.80
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   12    |  56.399%  |  89.758%  |  63.489%  |     61.252%     |   56.399%    |  75.089%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   12    |  75.089%  |     -     |     -     |     75.089%     |   75.089%    |  75.089%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   13    |   10    |   0.301368   |     -     |   47.24
#   13    |   20    |   0.296960   |     -     |   20.20
#   13    |   30    |   0.095501   |     -     |   24.33
#   13    |   40    |   0.079559   |     -     |   19.30
#   13    |   50    |   0.090728   |     -     |   24.03
#   13    |   52    |   0.080403   |     -     |   2.95
# ----------------------------------------------------------------------
#   13    |    -    |   0.175064   |  0.993330  |  142.78
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   13    |  56.363%  |  89.878%  |  63.784%  |     64.017%     |   56.363%    |  75.447%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   13    |  75.447%  |     -     |     -     |     75.447%     |   75.447%    |  75.447%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   14    |   10    |   0.274260   |     -     |   22.18
#   14    |   20    |   0.183793   |     -     |   20.06
#   14    |   30    |   0.075466   |     -     |   24.88
#   14    |   40    |   0.080043   |     -     |   20.36
#   14    |   50    |   0.063426   |     -     |   24.60
#   14    |   52    |   0.084042   |     -     |   3.14
# ----------------------------------------------------------------------
#   14    |    -    |   0.138697   |  1.012132  |  119.91
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   14    |  55.879%  |  89.878%  |  63.703%  |     57.939%     |   55.879%    |  76.043%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   14    |  76.043%  |     -     |     -     |     76.043%     |   76.043%    |  76.043%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   15    |   10    |   0.221764   |     -     |   22.48
#   15    |   20    |   0.211552   |     -     |   20.02
#   15    |   30    |   0.068383   |     -     |   24.58
#   15    |   40    |   0.060845   |     -     |   20.09
#   15    |   50    |   0.070249   |     -     |   24.81
#   15    |   52    |   0.056160   |     -     |   3.08
# ----------------------------------------------------------------------
#   15    |    -    |   0.128116   |  1.001171  |  119.72
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   15    |  55.759%  |  89.876%  |  63.659%  |     58.448%     |   55.759%    |  75.685%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   15    |  75.685%  |     -     |     -     |     75.685%     |   75.685%    |  75.685%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   16    |   10    |   0.275172   |     -     |   23.35
#   16    |   20    |   0.263093   |     -     |   20.22
#   16    |   30    |   0.063421   |     -     |   24.47
#   16    |   40    |   0.058622   |     -     |   20.30
#   16    |   50    |   0.051403   |     -     |   28.52
#   16    |   52    |   0.073188   |     -     |   3.23
# Epoch    16: reducing learning rate of group 0 to 9.0000e-05.
# ----------------------------------------------------------------------
#   16    |    -    |   0.144974   |  1.029202  |  125.03
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   16    |  56.317%  |  89.788%  |  63.613%  |     61.761%     |   56.317%    |  75.566%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   16    |  75.566%  |     -     |     -     |     75.566%     |   75.566%    |  75.566%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   17    |   10    |   0.177899   |     -     |   22.54
#   17    |   20    |   0.190322   |     -     |   20.85
#   17    |   30    |   0.044660   |     -     |   25.79
#   17    |   40    |   0.061880   |     -     |   20.28
#   17    |   50    |   0.043161   |     -     |   24.70
#   17    |   52    |   0.091251   |     -     |   3.04
# ----------------------------------------------------------------------
#   17    |    -    |   0.106531   |  0.992183  |  121.80
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   17    |  56.901%  |  89.872%  |  63.735%  |     64.822%     |   56.901%    |  76.043%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   17    |  76.043%  |     -     |     -     |     76.043%     |   76.043%    |  76.043%

# %%
test = test_process()
test_dataset = MixDataset(tp.max_seq_len, w2v, c2v, phraser, label2idx,  test['name'].values, test['description'].values)
test_sampler = SequentialSampler(test_dataset)
test_loader = DataLoader(test_dataset, sampler=test_sampler, batch_size=tp.batch_size)

# %%
result = kfold_inference(test_loader, tp, Textcnn, './checkpoint/textcnn_fgm', 5,device)
result['pred'] = result['pred_avg']
result_process(result, label2idx, './submit/textcnn_fgm_5fold_avg.csv')
