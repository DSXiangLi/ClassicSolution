# %%
import warnings
warnings.filterwarnings(action='ignore')

import torch 
import time 
from sklearn.model_selection import KFold
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data.sampler import SequentialSampler, RandomSampler
from torch.utils.data.dataloader import DataLoader
from torch.utils.tensorboard import SummaryWriter
from gensim.models.phrases import Phrases
from gensim.models import Word2Vec

from src.train_utils import set_seed, ModelSave, get_torch_device, EarlyStop, TrainParams
from src.evaluation import multi_cls_report, classification_inference
from src.metric import  multi_cls_metrics,multi_cls_log
from src.dataset.tokenizer import GensimTokenizer

from iflytek_app.dataset import MixDataset
from iflytek_app.models import Fasttext
from iflytek_app.process import train_process, test_process, result_process

device = get_torch_device()
set_seed()
# Out:
# No GPU available, using the CPU instead.

# %%
c2v = GensimTokenizer( Word2Vec.load('./checkpoint/char_min1_win5_sg_d100'))
w2v = GensimTokenizer(Word2Vec.load('./checkpoint/phrase_min1_win5_sg_d100'))
w2v.init_vocab()
c2v.init_vocab()
phraser = Phrases.load('./checkpoint/phrase_tokenizer')
df, label2idx = train_process()
# Out:
#                 id           l1           l2          len
# count  4199.000000  4199.000000  4199.000000  4199.000000
# mean   2099.000000     8.969278    37.087878    46.057156
# std    1212.291219     4.576621    79.204914    79.332999
# min       0.000000     2.000000     1.000000     4.000000
# 25%    1049.500000     5.000000     6.000000    15.000000
# 50%    2099.000000     8.000000    12.000000    22.000000
# 75%    3148.500000    12.000000    26.000000    36.000000
# max    4198.000000    32.000000   946.000000   961.000000
# {'14784131 14858934 14784131 14845064': 0, '14852788 14717848 15639958 15632020': 1, '14844856 14724258 14925237 14854807': 2, '14925756 15639967 14853254 14728639': 3, '14844593 14924945': 4, '15709098 14716590 14924703 14779559': 5, '14726332 14728344 14854542 14844591': 6, '14858934 15636660 15704193 14849963': 7, '15710359 14847407 14845602 14859696': 8, '14794687 14782344': 9, '15630486 15702410 14718849 15709093': 10, '15632285 15706536 14721977 14925219': 11, '14782903 15634620 15638402 15706300': 12, '14844093 15705739 14854331 15699885': 13, '14856354 14844592': 14, '14847385 14844587 14848641 14847398': 15, '14783134 15697333 14854817 14925479': 16, '14924216 14781104 14717848 14791612': 17, '14786237 15697082 14722731 14924977': 18}

# %%
log_steps = 10
save_steps = 20
kfold = 5
tp = TrainParams(
    epoch_size=30,
    lr=1e-3,
    loss_fn=nn.CrossEntropyLoss(),
    max_seq_len=1000,
    batch_size=64,
    dropout_rate=0.5,
    label_size = len(label2idx),
    vocab_size = c2v.vocab_size,
    embedding_dim = c2v.embedding_size + w2v.embedding_size,
    num_train_steps=int(df.shape[0]/kfold * (kfold-1)), 
    embedding1=c2v.embedding,
    embedding2=w2v.embedding,
    hidden_size=200,
    diff_lr =False,
    early_stop_params = {
        'monitor':'f1_micro',
        'mode':'max',
        'min_delta': 0,
        'patience':3,
        'verbose':False
    },
    scheduler_params={'mode': 'max',
                     'factor': 0.3,
                     'patience': 1,
                     'verbose': True,
                     'threshold':0.0001,
                     'threshold_mode':'rel',
                     'cooldown':0,
                     'min_lr':1e-6}
)


kf = KFold(n_splits=5, shuffle=True, random_state=24)
for fold,(train_index, valid_index) in enumerate(kf.split(df)):
    train, valid = df.iloc[train_index], df.iloc[valid_index]

    train_dataset = MixDataset(tp.max_seq_len, w2v, c2v, phraser, label2idx, 
                               train['name'].values, train['description'].values, train['label'].values)
    valid_dataset = MixDataset(tp.max_seq_len, w2v, c2v, phraser, label2idx, 
                               valid['name'].values, valid['description'].values, valid['label'].values)
    train_sampler = RandomSampler(train_dataset)
    valid_sampler = SequentialSampler(valid_dataset)
    train_loader = DataLoader(train_dataset, sampler=train_sampler, batch_size=tp.batch_size)
    valid_loader = DataLoader(valid_dataset, sampler=valid_sampler, batch_size=tp.batch_size)
    
    CKPT = './checkpoint/fasttext/k{}'.format(fold)
    saver = ModelSave(CKPT, continue_train=False)
    saver.init()
    tb = SummaryWriter(CKPT)
    es = EarlyStop(**tp.early_stop_params)
    global_step = 0

    
    model = Fasttext(tp)
    optimizer, scheduler = model.get_optimizer()
    
    for epoch_i in range(tp['epoch_size']):
        if global_step==1:
            print(model)
        print(f"{'Epoch':^7} | {'Batch':^7} | {'Train Loss':^12} | {'Val Loss':^10}  | {'Elapsed':^9}")
        print("-"*60)

        # Measure the elapsed time of each epoch
        t0_epoch, t0_batch = time.time(), time.time()
        total_loss, batch_loss, batch_counts = 0, 0, 0

        model.train()
        for step, batch in enumerate(train_loader):
            global_step +=1
            batch_counts +=1

            #Forward propogate
            model.zero_grad()
            feature = {k:v.to(device) for k, v in batch.items()}
            logits  = model(feature)
            loss = model.compute_loss(feature, logits)
            batch_loss += loss.item()
            total_loss += loss.item()
            loss.backward()
            
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            optimizer.step()

            # Log steps for train loss logging
            if (step % log_steps == 0 and step != 0) or (step == len(train_loader) - 1):
                time_elapsed = time.time() - t0_batch
                print(f"{epoch_i + 1:^7} | {step:^7} | {batch_loss / batch_counts:^12.6f} | {'-':^9} | {time_elapsed:^9.2f}")
                tb.add_scalar('loss/batch_train', batch_loss / batch_counts, global_step=global_step)
                batch_loss, batch_counts = 0, 0
                t0_batch = time.time()

            # Save steps for ckpt saving and dev evaluation
            if (step % save_steps == 0 and step != 0) or (step == len(train_loader) - 1):
                val_metrics = multi_cls_metrics(model, valid_loader, device)
                for key, val in val_metrics.items():
                    tb.add_scalar(f'metric/{key}', val, global_step=global_step)
                avg_train_loss = total_loss / step
                tb.add_scalars('loss/train_valid',{'loss': avg_train_loss,
                                                    'oss': val_metrics['val_loss']}, global_step=global_step)
                saver(total_loss / step, val_metrics['val_loss'], epoch_i, global_step, model, optimizer, scheduler)

        # On Epoch End: calcualte train & valid loss and log overall metrics
        time_elapsed = time.time() - t0_epoch
        val_metrics = multi_cls_metrics(model, valid_loader, device)
        avg_train_loss = total_loss / step
        scheduler.step(val_metrics['f1_micro'])
        print("-"*70)
        print(f"{epoch_i + 1:^7} | {'-':^7} | {avg_train_loss:^12.6f} | {val_metrics['val_loss']:^10.6f} | {time_elapsed:^9.2f}")
        multi_cls_log(epoch_i, val_metrics)
        print("\n")
        if es.check(val_metrics):
            break
# Out:
# ./checkpoint/fasttext/k0 model cleaned
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    1    |   10    |   3.224917   |     -     |   7.85
#    1    |   20    |   2.270853   |     -     |   6.31
#    1    |   30    |   2.546636   |     -     |   11.26
#    1    |   40    |   2.370054   |     -     |   6.70
#    1    |   50    |   2.374516   |     -     |   9.62
#    1    |   52    |   2.383209   |     -     |   0.91
# ----------------------------------------------------------------------
#    1    |    -    |   2.612713   |  2.366268  |   45.82
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    1    |  15.920%  |  67.281%  |  21.458%  |     24.859%     |   15.920%    |  31.905%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    1    |  31.905%  |     -     |     -     |     31.905%     |   31.905%    |  31.905%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    2    |   10    |   2.371449   |     -     |   6.81
#    2    |   20    |   1.970359   |     -     |   6.73
#    2    |   30    |   1.889994   |     -     |   9.28
#    2    |   40    |   1.898468   |     -     |   6.15
#    2    |   50    |   1.878098   |     -     |   9.35
#    2    |   52    |   1.799466   |     -     |   0.97
# ----------------------------------------------------------------------
#    2    |    -    |   2.039501   |  1.820098  |   42.47
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    2    |  20.894%  |  78.404%  |  38.302%  |     31.105%     |   20.894%    |  45.238%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    2    |  45.238%  |     -     |     -     |     45.238%     |   45.238%    |  45.238%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    3    |   10    |   2.003531   |     -     |   7.43
#    3    |   20    |   1.556114   |     -     |   6.52
#    3    |   30    |   1.476520   |     -     |   9.83
#    3    |   40    |   1.469203   |     -     |   6.28
#    3    |   50    |   1.586357   |     -     |   10.73
#    3    |   52    |   1.334184   |     -     |   0.91
# ----------------------------------------------------------------------
#    3    |    -    |   1.645945   |  1.647349  |   44.75
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    3    |  34.398%  |  82.022%  |  40.196%  |     43.211%     |   34.398%    |  52.976%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    3    |  52.976%  |     -     |     -     |     52.976%     |   52.976%    |  52.976%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    4    |   10    |   1.792777   |     -     |   7.35
#    4    |   20    |   1.480637   |     -     |   6.37
#    4    |   30    |   1.245446   |     -     |   9.00
#    4    |   40    |   1.272775   |     -     |   6.20
#    4    |   50    |   1.189013   |     -     |   9.23
#    4    |   52    |   1.203237   |     -     |   0.89
# ----------------------------------------------------------------------
#    4    |    -    |   1.423187   |  1.527039  |   42.15
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    4    |  39.064%  |  85.282%  |  49.183%  |     51.960%     |   39.064%    |  56.667%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    4    |  56.667%  |     -     |     -     |     56.667%     |   56.667%    |  56.667%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    5    |   10    |   1.205454   |     -     |   7.22
#    5    |   20    |   1.047388   |     -     |   6.28
#    5    |   30    |   1.067945   |     -     |   9.02
#    5    |   40    |   1.181446   |     -     |   6.15
#    5    |   50    |   1.010629   |     -     |   9.87
#    5    |   52    |   0.785331   |     -     |   1.09
# ----------------------------------------------------------------------
#    5    |    -    |   1.113553   |  1.532248  |   43.20
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    5    |  38.184%  |  85.636%  |  55.326%  |     44.420%     |   38.184%    |  58.214%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    5    |  58.214%  |     -     |     -     |     58.214%     |   58.214%    |  58.214%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    6    |   10    |   0.984416   |     -     |   7.50
#    6    |   20    |   0.972616   |     -     |   6.64
#    6    |   30    |   0.870677   |     -     |   9.81
#    6    |   40    |   1.016908   |     -     |   6.94
#    6    |   50    |   0.993387   |     -     |   10.48
#    6    |   52    |   0.808082   |     -     |   0.96
# ----------------------------------------------------------------------
#    6    |    -    |   0.980397   |  1.341707  |   45.70
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    6    |  48.066%  |  87.230%  |  56.282%  |     51.783%     |   48.066%    |  66.190%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    6    |  66.190%  |     -     |     -     |     66.190%     |   66.190%    |  66.190%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    7    |   10    |   1.136366   |     -     |   7.32
#    7    |   20    |   0.827667   |     -     |   6.87
#    7    |   30    |   0.766888   |     -     |   9.48
#    7    |   40    |   0.751921   |     -     |   6.10
#    7    |   50    |   0.850731   |     -     |   8.95
#    7    |   52    |   0.711210   |     -     |   0.94
# ----------------------------------------------------------------------
#    7    |    -    |   0.882587   |  1.286247  |   42.69
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    7    |  46.739%  |  87.293%  |  53.827%  |     57.913%     |   46.739%    |  65.476%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    7    |  65.476%  |     -     |     -     |     65.476%     |   65.476%    |  65.476%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    8    |   10    |   0.666478   |     -     |   6.77
#    8    |   20    |   0.699356   |     -     |   6.23
#    8    |   30    |   0.777751   |     -     |   9.12
#    8    |   40    |   0.680992   |     -     |   6.67
#    8    |   50    |   0.605592   |     -     |   12.38
#    8    |   52    |   1.003255   |     -     |   1.54
# ----------------------------------------------------------------------
#    8    |    -    |   0.711052   |  1.333730  |   46.61
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    8    |  49.918%  |  88.368%  |  61.145%  |     55.741%     |   49.918%    |  67.024%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    8    |  67.024%  |     -     |     -     |     67.024%     |   67.024%    |  67.024%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    9    |   10    |   0.549597   |     -     |   8.22
#    9    |   20    |   0.557417   |     -     |   7.88
#    9    |   30    |   0.650993   |     -     |   10.10
#    9    |   40    |   0.572504   |     -     |   6.49
#    9    |   50    |   0.654309   |     -     |   10.58
#    9    |   52    |   0.492427   |     -     |   1.06
# ----------------------------------------------------------------------
#    9    |    -    |   0.603512   |  1.219849  |   47.78
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    9    |  49.916%  |  88.522%  |  58.931%  |     57.370%     |   49.916%    |  69.643%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    9    |  69.643%  |     -     |     -     |     69.643%     |   69.643%    |  69.643%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   10    |   10    |   0.637990   |     -     |   7.79
#   10    |   20    |   0.440318   |     -     |   6.65
#   10    |   30    |   0.620638   |     -     |   10.17
#   10    |   40    |   0.451244   |     -     |   6.24
#   10    |   50    |   0.457651   |     -     |   9.37
#   10    |   52    |   0.262499   |     -     |   0.93
# ----------------------------------------------------------------------
#   10    |    -    |   0.523873   |  1.322113  |   44.25
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   10    |  49.933%  |  88.027%  |  61.240%  |     60.818%     |   49.933%    |  69.524%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   10    |  69.524%  |     -     |     -     |     69.524%     |   69.524%    |  69.524%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   11    |   10    |   0.454344   |     -     |   7.34
#   11    |   20    |   0.418373   |     -     |   6.61
#   11    |   30    |   0.374432   |     -     |   9.46
#   11    |   40    |   0.319490   |     -     |   7.05
#   11    |   50    |   0.415023   |     -     |   11.49
#   11    |   52    |   0.314462   |     -     |   1.05
# Epoch    11: reducing learning rate of group 0 to 3.0000e-04.
# ----------------------------------------------------------------------
#   11    |    -    |   0.401921   |  1.276767  |   46.19
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   11    |  48.971%  |  88.671%  |  62.062%  |     57.938%     |   48.971%    |  69.405%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   11    |  69.405%  |     -     |     -     |     69.405%     |   69.405%    |  69.405%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   12    |   10    |   0.366515   |     -     |   7.25
#   12    |   20    |   0.275862   |     -     |   6.60
#   12    |   30    |   0.319429   |     -     |   10.78
#   12    |   40    |   0.269739   |     -     |   7.88
#   12    |   50    |   0.262303   |     -     |   10.52
#   12    |   52    |   0.254985   |     -     |   0.94
# ----------------------------------------------------------------------
#   12    |    -    |   0.304134   |  1.324902  |   47.14
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   12    |  57.116%  |  88.505%  |  61.252%  |     63.029%     |   57.116%    |  71.548%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   12    |  71.548%  |     -     |     -     |     71.548%     |   71.548%    |  71.548%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   13    |   10    |   0.246926   |     -     |   7.17
#   13    |   20    |   0.257667   |     -     |   6.46
#   13    |   30    |   0.250819   |     -     |   9.22
#   13    |   40    |   0.230639   |     -     |   6.16
#   13    |   50    |   0.285511   |     -     |   9.16
#   13    |   52    |   0.235677   |     -     |   0.93
# ----------------------------------------------------------------------
#   13    |    -    |   0.258344   |  1.263042  |   42.31
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   13    |  54.841%  |  88.379%  |  66.175%  |     66.181%     |   54.841%    |  71.786%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   13    |  71.786%  |     -     |     -     |     71.786%     |   71.786%    |  71.786%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   14    |   10    |   0.193543   |     -     |   7.28
#   14    |   20    |   0.228233   |     -     |   7.40
#   14    |   30    |   0.241328   |     -     |   9.76
#   14    |   40    |   0.282842   |     -     |   6.49
#   14    |   50    |   0.217301   |     -     |   9.75
#   14    |   52    |   0.307709   |     -     |   0.99
# ----------------------------------------------------------------------
#   14    |    -    |   0.239258   |  1.276211  |   44.98
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   14    |  54.664%  |  88.490%  |  62.309%  |     66.604%     |   54.664%    |  71.190%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   14    |  71.190%  |     -     |     -     |     71.190%     |   71.190%    |  71.190%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   15    |   10    |   0.186431   |     -     |   7.49
#   15    |   20    |   0.235913   |     -     |   6.31
#   15    |   30    |   0.198714   |     -     |   8.99
#   15    |   40    |   0.195354   |     -     |   5.98
#   15    |   50    |   0.225964   |     -     |   8.76
#   15    |   52    |   0.245129   |     -     |   0.89
# Epoch    15: reducing learning rate of group 0 to 9.0000e-05.
# ----------------------------------------------------------------------
#   15    |    -    |   0.213470   |  1.320475  |   41.44
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   15    |  55.837%  |  88.401%  |  61.537%  |     61.587%     |   55.837%    |  71.786%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   15    |  71.786%  |     -     |     -     |     71.786%     |   71.786%    |  71.786%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   16    |   10    |   0.190246   |     -     |   6.79
#   16    |   20    |   0.194375   |     -     |   6.29
#   16    |   30    |   0.217870   |     -     |   8.93
#   16    |   40    |   0.178064   |     -     |   6.05
#   16    |   50    |   0.179638   |     -     |   8.99
#   16    |   52    |   0.165072   |     -     |   0.88
# ----------------------------------------------------------------------
#   16    |    -    |   0.194660   |  1.296098  |   40.98
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   16    |  55.754%  |  88.189%  |  63.638%  |     65.080%     |   55.754%    |  72.024%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   16    |  72.024%  |     -     |     -     |     72.024%     |   72.024%    |  72.024%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   17    |   10    |   0.197790   |     -     |   7.13
#   17    |   20    |   0.196953   |     -     |   6.82
#   17    |   30    |   0.201951   |     -     |   9.49
#   17    |   40    |   0.169108   |     -     |   6.46
#   17    |   50    |   0.160780   |     -     |   11.76
#   17    |   52    |   0.140576   |     -     |   1.04
# ----------------------------------------------------------------------
#   17    |    -    |   0.187399   |  1.293956  |   46.88
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   17    |  55.093%  |  88.250%  |  62.201%  |     66.680%     |   55.093%    |  72.500%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   17    |  72.500%  |     -     |     -     |     72.500%     |   72.500%    |  72.500%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   18    |   10    |   0.176514   |     -     |   7.52
#   18    |   20    |   0.184990   |     -     |   6.43
#   18    |   30    |   0.160720   |     -     |   9.16
#   18    |   40    |   0.194923   |     -     |   6.35
#   18    |   50    |   0.196839   |     -     |   9.30
#   18    |   52    |   0.348763   |     -     |   0.89
# ----------------------------------------------------------------------
#   18    |    -    |   0.192575   |  1.256996  |   43.10
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   18    |  55.241%  |  88.386%  |  62.889%  |     68.282%     |   55.241%    |  72.024%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   18    |  72.024%  |     -     |     -     |     72.024%     |   72.024%    |  72.024%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   19    |   10    |   0.208244   |     -     |   6.98
#   19    |   20    |   0.163124   |     -     |   6.63
#   19    |   30    |   0.140101   |     -     |   10.45
#   19    |   40    |   0.172890   |     -     |   6.32
#   19    |   50    |   0.183033   |     -     |   9.24
#   19    |   52    |   0.139950   |     -     |   0.93
# Epoch    19: reducing learning rate of group 0 to 2.7000e-05.
# ----------------------------------------------------------------------
#   19    |    -    |   0.176193   |  1.302670  |   43.60
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   19    |  56.242%  |  88.410%  |  66.395%  |     65.241%     |   56.242%    |  72.262%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   19    |  72.262%  |     -     |     -     |     72.262%     |   72.262%    |  72.262%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   20    |   10    |   0.194086   |     -     |   6.92
#   20    |   20    |   0.176106   |     -     |   6.23
#   20    |   30    |   0.178146   |     -     |   8.97
#   20    |   40    |   0.150928   |     -     |   6.16
#   20    |   50    |   0.146991   |     -     |   9.50
#   20    |   52    |   0.209784   |     -     |   0.92
# ----------------------------------------------------------------------
#   20    |    -    |   0.174543   |  1.297908  |   42.08
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   20    |  56.077%  |  88.196%  |  63.584%  |     64.085%     |   56.077%    |  72.738%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   20    |  72.738%  |     -     |     -     |     72.738%     |   72.738%    |  72.738%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   21    |   10    |   0.177860   |     -     |   7.70
#   21    |   20    |   0.184440   |     -     |   6.61
#   21    |   30    |   0.132609   |     -     |   10.06
#   21    |   40    |   0.191630   |     -     |   6.64
#   21    |   50    |   0.164208   |     -     |   10.86
#   21    |   52    |   0.146368   |     -     |   1.22
# ----------------------------------------------------------------------
#   21    |    -    |   0.172655   |  1.285927  |   46.65
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   21    |  54.853%  |  88.230%  |  63.430%  |     66.015%     |   54.853%    |  71.905%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   21    |  71.905%  |     -     |     -     |     71.905%     |   71.905%    |  71.905%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   22    |   10    |   0.166935   |     -     |   7.35
#   22    |   20    |   0.171542   |     -     |   6.62
#   22    |   30    |   0.174922   |     -     |   8.96
#   22    |   40    |   0.168803   |     -     |   6.87
#   22    |   50    |   0.153470   |     -     |   9.88
#   22    |   52    |   0.132468   |     -     |   0.97
# Epoch    22: reducing learning rate of group 0 to 8.1000e-06.
# ----------------------------------------------------------------------
#   22    |    -    |   0.169011   |  1.300422  |   44.18
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   22    |  55.604%  |  88.249%  |  66.169%  |     64.355%     |   55.604%    |  72.381%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   22    |  72.381%  |     -     |     -     |     72.381%     |   72.381%    |  72.381%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   23    |   10    |   0.172424   |     -     |   6.76
#   23    |   20    |   0.197955   |     -     |   6.35
#   23    |   30    |   0.160062   |     -     |   10.04
#   23    |   40    |   0.177815   |     -     |   6.74
#   23    |   50    |   0.152603   |     -     |   9.29
#   23    |   52    |   0.101374   |     -     |   0.91
# ----------------------------------------------------------------------
#   23    |    -    |   0.172765   |  1.276763  |   43.11
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   23    |  55.636%  |  88.288%  |  66.375%  |     64.087%     |   55.636%    |  72.619%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   23    |  72.619%  |     -     |     -     |     72.619%     |   72.619%    |  72.619%
#
#
#
#
# Warning: [WinError 3] 系统找不到指定的路径。: './checkpoint/fasttext/k1' not exists
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    1    |   10    |   3.408619   |     -     |   7.08
#    1    |   20    |   2.255427   |     -     |   6.25
#    1    |   30    |   2.512786   |     -     |   9.48
#    1    |   40    |   2.438105   |     -     |   6.16
#    1    |   50    |   2.271601   |     -     |   9.21
#    1    |   52    |   2.323963   |     -     |   0.86
# ----------------------------------------------------------------------
#    1    |    -    |   2.633114   |  2.234032  |   42.21
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    1    |  15.654%  |  64.314%  |  29.083%  |     17.850%     |   15.654%    |  36.548%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    1    |  36.548%  |     -     |     -     |     36.548%     |   36.548%    |  36.548%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    2    |   10    |   2.346960   |     -     |   7.05
#    2    |   20    |   1.774379   |     -     |   6.22
#    2    |   30    |   1.893611   |     -     |   9.18
#    2    |   40    |   1.901972   |     -     |   6.53
#    2    |   50    |   1.862276   |     -     |   9.35
#    2    |   52    |   1.652329   |     -     |   0.93
# ----------------------------------------------------------------------
#    2    |    -    |   1.989300   |  1.769946  |   42.47
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    2    |  25.909%  |  76.996%  |  40.556%  |     32.119%     |   25.909%    |  48.690%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    2    |  48.690%  |     -     |     -     |     48.690%     |   48.690%    |  48.690%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    3    |   10    |   1.903391   |     -     |   6.84
#    3    |   20    |   1.799546   |     -     |   6.31
#    3    |   30    |   1.465147   |     -     |   9.07
#    3    |   40    |   1.553475   |     -     |   6.20
#    3    |   50    |   1.494883   |     -     |   8.99
#    3    |   52    |   1.568102   |     -     |   0.94
# ----------------------------------------------------------------------
#    3    |    -    |   1.677000   |  1.505232  |   41.52
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    3    |  34.995%  |  78.176%  |  47.968%  |     52.154%     |   34.995%    |  55.357%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    3    |  55.357%  |     -     |     -     |     55.357%     |   55.357%    |  55.357%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    4    |   10    |   1.522299   |     -     |   7.11
#    4    |   20    |   1.349931   |     -     |   6.30
#    4    |   30    |   1.360126   |     -     |   9.47
#    4    |   40    |   1.243973   |     -     |   6.12
#    4    |   50    |   1.184111   |     -     |   9.15
#    4    |   52    |   1.369381   |     -     |   0.94
# ----------------------------------------------------------------------
#    4    |    -    |   1.362797   |  1.461028  |   42.12
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    4    |  41.259%  |  79.853%  |  52.915%  |     49.296%     |   41.259%    |  58.452%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    4    |  58.452%  |     -     |     -     |     58.452%     |   58.452%    |  58.452%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    5    |   10    |   1.216261   |     -     |   6.75
#    5    |   20    |   1.136214   |     -     |   6.29
#    5    |   30    |   1.168734   |     -     |   9.03
#    5    |   40    |   1.067009   |     -     |   6.12
#    5    |   50    |   1.162922   |     -     |   9.01
#    5    |   52    |   0.897225   |     -     |   0.88
# ----------------------------------------------------------------------
#    5    |    -    |   1.163887   |  1.340055  |   41.08
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    5    |  43.944%  |  81.146%  |  56.826%  |     60.524%     |   43.944%    |  61.071%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    5    |  61.071%  |     -     |     -     |     61.071%     |   61.071%    |  61.071%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    6    |   10    |   1.446586   |     -     |   6.92
#    6    |   20    |   0.990657   |     -     |   6.41
#    6    |   30    |   1.171753   |     -     |   9.05
#    6    |   40    |   0.924714   |     -     |   6.00
#    6    |   50    |   1.081643   |     -     |   9.09
#    6    |   52    |   0.818266   |     -     |   0.99
# ----------------------------------------------------------------------
#    6    |    -    |   1.139166   |  1.147095  |   41.75
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    6    |  51.371%  |  82.972%  |  61.109%  |     63.637%     |   51.371%    |  67.619%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    6    |  67.619%  |     -     |     -     |     67.619%     |   67.619%    |  67.619%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    7    |   10    |   1.080556   |     -     |   7.37
#    7    |   20    |   0.915997   |     -     |   6.29
#    7    |   30    |   0.860090   |     -     |   9.07
#    7    |   40    |   0.737773   |     -     |   6.01
#    7    |   50    |   0.896897   |     -     |   8.59
#    7    |   52    |   1.156845   |     -     |   0.93
# ----------------------------------------------------------------------
#    7    |    -    |   0.928988   |  1.115368  |   40.50
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    7    |  54.448%  |  83.136%  |  64.604%  |     66.746%     |   54.448%    |  69.762%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    7    |  69.762%  |     -     |     -     |     69.762%     |   69.762%    |  69.762%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    8    |   10    |   0.782642   |     -     |   4.34
#    8    |   20    |   0.859845   |     -     |   3.94
#    8    |   30    |   0.732968   |     -     |   7.23
#    8    |   40    |   0.827255   |     -     |   6.54
#    8    |   50    |   0.730969   |     -     |   10.24
#    8    |   52    |   0.318910   |     -     |   0.97
# ----------------------------------------------------------------------
#    8    |    -    |   0.783793   |  1.097297  |   36.35
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    8    |  54.907%  |  83.412%  |  65.480%  |     64.762%     |   54.907%    |  70.357%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    8    |  70.357%  |     -     |     -     |     70.357%     |   70.357%    |  70.357%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    9    |   10    |   0.753245   |     -     |   6.80
#    9    |   20    |   0.611404   |     -     |   6.75
#    9    |   30    |   0.681795   |     -     |   9.28
#    9    |   40    |   0.704104   |     -     |   6.16
#    9    |   50    |   0.571115   |     -     |   9.20
#    9    |   52    |   0.444837   |     -     |   0.94
# ----------------------------------------------------------------------
#    9    |    -    |   0.670376   |  1.126807  |   42.15
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    9    |  55.463%  |  82.433%  |  66.978%  |     70.349%     |   55.463%    |  71.548%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    9    |  71.548%  |     -     |     -     |     71.548%     |   71.548%    |  71.548%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   10    |   10    |   0.643820   |     -     |   6.88
#   10    |   20    |   0.568788   |     -     |   6.17
#   10    |   30    |   0.535542   |     -     |   9.15
#   10    |   40    |   0.507142   |     -     |   6.00
#   10    |   50    |   0.412451   |     -     |   9.01
#   10    |   52    |   0.326729   |     -     |   0.86
# ----------------------------------------------------------------------
#   10    |    -    |   0.537975   |  1.213377  |   41.13
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   10    |  60.661%  |  82.894%  |  67.652%  |     66.058%     |   60.661%    |  71.548%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   10    |  71.548%  |     -     |     -     |     71.548%     |   71.548%    |  71.548%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   11    |   10    |   0.433374   |     -     |   6.77
#   11    |   20    |   0.408422   |     -     |   6.28
#   11    |   30    |   0.437317   |     -     |   9.07
#   11    |   40    |   0.472725   |     -     |   6.06
#   11    |   50    |   0.382843   |     -     |   8.98
#   11    |   52    |   0.366404   |     -     |   0.89
# ----------------------------------------------------------------------
#   11    |    -    |   0.432942   |  1.110561  |   41.06
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   11    |  57.792%  |  83.089%  |  68.006%  |     67.386%     |   57.792%    |  71.667%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   11    |  71.667%  |     -     |     -     |     71.667%     |   71.667%    |  71.667%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   12    |   10    |   0.433257   |     -     |   6.88
#   12    |   20    |   0.327328   |     -     |   6.25
#   12    |   30    |   0.313048   |     -     |   9.01
#   12    |   40    |   0.333479   |     -     |   6.03
#   12    |   50    |   0.293454   |     -     |   9.01
#   12    |   52    |   0.353201   |     -     |   0.91
# ----------------------------------------------------------------------
#   12    |    -    |   0.348949   |  1.155009  |   41.15
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   12    |  60.272%  |  83.055%  |  68.731%  |     66.648%     |   60.272%    |  72.500%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   12    |  72.500%  |     -     |     -     |     72.500%     |   72.500%    |  72.500%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   13    |   10    |   0.257783   |     -     |   6.92
#   13    |   20    |   0.247522   |     -     |   6.15
#   13    |   30    |   0.285366   |     -     |   9.13
#   13    |   40    |   0.295813   |     -     |   5.84
#   13    |   50    |   0.285817   |     -     |   8.90
#   13    |   52    |   0.212187   |     -     |   0.93
# ----------------------------------------------------------------------
#   13    |    -    |   0.277022   |  1.150974  |   40.98
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   13    |  59.749%  |  83.187%  |  67.812%  |     70.079%     |   59.749%    |  70.595%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   13    |  70.595%  |     -     |     -     |     70.595%     |   70.595%    |  70.595%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   14    |   10    |   0.197863   |     -     |   6.87
#   14    |   20    |   0.226233   |     -     |   6.28
#   14    |   30    |   0.225058   |     -     |   9.01
#   14    |   40    |   0.194528   |     -     |   6.03
#   14    |   50    |   0.182775   |     -     |   8.94
#   14    |   52    |   0.306056   |     -     |   0.94
# ----------------------------------------------------------------------
#   14    |    -    |   0.212972   |  1.171936  |   41.16
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   14    |  61.482%  |  83.346%  |  69.417%  |     68.152%     |   61.482%    |  74.048%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   14    |  74.048%  |     -     |     -     |     74.048%     |   74.048%    |  74.048%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   15    |   10    |   0.173898   |     -     |   6.88
#   15    |   20    |   0.146419   |     -     |   6.29
#   15    |   30    |   0.179862   |     -     |   9.62
#   15    |   40    |   0.195154   |     -     |   5.81
#   15    |   50    |   0.191620   |     -     |   8.96
#   15    |   52    |   0.205055   |     -     |   0.89
# ----------------------------------------------------------------------
#   15    |    -    |   0.181799   |  1.235160  |   41.44
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   15    |  64.211%  |  82.899%  |  68.469%  |     68.340%     |   64.211%    |  74.405%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   15    |  74.405%  |     -     |     -     |     74.405%     |   74.405%    |  74.405%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   16    |   10    |   0.137351   |     -     |   6.88
#   16    |   20    |   0.145878   |     -     |   6.13
#   16    |   30    |   0.187329   |     -     |   9.03
#   16    |   40    |   0.157437   |     -     |   6.39
#   16    |   50    |   0.148765   |     -     |   9.11
#   16    |   52    |   0.288217   |     -     |   0.97
# ----------------------------------------------------------------------
#   16    |    -    |   0.163104   |  1.243922  |   41.52
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   16    |  65.558%  |  82.963%  |  68.954%  |     68.347%     |   65.558%    |  74.881%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   16    |  74.881%  |     -     |     -     |     74.881%     |   74.881%    |  74.881%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   17    |   10    |   0.142342   |     -     |   6.75
#   17    |   20    |   0.140421   |     -     |   6.25
#   17    |   30    |   0.107524   |     -     |   8.92
#   17    |   40    |   0.144867   |     -     |   6.00
#   17    |   50    |   0.132632   |     -     |   8.96
#   17    |   52    |   0.239808   |     -     |   0.89
# ----------------------------------------------------------------------
#   17    |    -    |   0.140381   |  1.282214  |   40.76
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   17    |  61.776%  |  82.844%  |  68.202%  |     65.231%     |   61.776%    |  73.810%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   17    |  73.810%  |     -     |     -     |     73.810%     |   73.810%    |  73.810%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   18    |   10    |   0.106177   |     -     |   6.95
#   18    |   20    |   0.100655   |     -     |   6.18
#   18    |   30    |   0.110378   |     -     |   8.92
#   18    |   40    |   0.135659   |     -     |   5.90
#   18    |   50    |   0.116228   |     -     |   9.10
#   18    |   52    |   0.113377   |     -     |   0.91
# Epoch    18: reducing learning rate of group 0 to 3.0000e-04.
# ----------------------------------------------------------------------
#   18    |    -    |   0.115844   |  1.297500  |   40.98
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   18    |  62.172%  |  83.057%  |  67.772%  |     67.034%     |   62.172%    |  71.905%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   18    |  71.905%  |     -     |     -     |     71.905%     |   71.905%    |  71.905%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   19    |   10    |   0.078726   |     -     |   6.78
#   19    |   20    |   0.109102   |     -     |   6.33
#   19    |   30    |   0.075526   |     -     |   9.08
#   19    |   40    |   0.098083   |     -     |   5.93
#   19    |   50    |   0.100771   |     -     |   8.93
#   19    |   52    |   0.051608   |     -     |   0.92
# ----------------------------------------------------------------------
#   19    |    -    |   0.092385   |  1.283047  |   41.00
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   19    |  60.650%  |  83.203%  |  68.061%  |     66.600%     |   60.650%    |  72.857%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ...
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    5    |   10    |   1.796744   |     -     |   6.88
#    5    |   20    |   1.344428   |     -     |   6.26
#    5    |   30    |   1.099994   |     -     |   9.20
#    5    |   40    |   1.087989   |     -     |   6.14
#    5    |   50    |   1.097705   |     -     |   9.06
#    5    |   52    |   1.197967   |     -     |   0.93
# ----------------------------------------------------------------------
#    5    |    -    |   1.316563   |  1.230427  |   41.61
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    5    |  40.613%  |  83.026%  |  50.509%  |     53.586%     |   40.613%    |  65.316%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    5    |  65.316%  |     -     |     -     |     65.316%     |   65.316%    |  65.316%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    6    |   10    |   1.317933   |     -     |   7.73
#    6    |   20    |   1.042992   |     -     |   7.41
#    6    |   30    |   1.033633   |     -     |   9.42
#    6    |   40    |   0.942870   |     -     |   8.23
#    6    |   50    |   1.021170   |     -     |   10.52
#    6    |   52    |   0.901086   |     -     |   1.00
# ----------------------------------------------------------------------
#    6    |    -    |   1.090502   |  1.210664  |   47.90
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    6    |  43.758%  |  85.605%  |  51.727%  |     55.738%     |   43.758%    |  64.839%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    6    |  64.839%  |     -     |     -     |     64.839%     |   64.839%    |  64.839%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    7    |   10    |   0.800441   |     -     |   8.60
#    7    |   20    |   0.912879   |     -     |   7.15
#    7    |   30    |   0.851826   |     -     |   10.35
#    7    |   40    |   0.871137   |     -     |   6.91
#    7    |   50    |   0.784442   |     -     |   10.20
#    7    |   52    |   0.840501   |     -     |   0.89
# ----------------------------------------------------------------------
#    7    |    -    |   0.859398   |  1.156609  |   47.48
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    7    |  47.701%  |  84.670%  |  54.756%  |     55.511%     |   47.701%    |  66.985%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    7    |  66.985%  |     -     |     -     |     66.985%     |   66.985%    |  66.985%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    8    |   10    |   0.906157   |     -     |   7.70
#    8    |   20    |   0.714638   |     -     |   7.11
#    8    |   30    |   0.710785   |     -     |   10.30
#    8    |   40    |   0.634471   |     -     |   7.89
#    8    |   50    |   0.668708   |     -     |   10.15
#    8    |   52    |   0.639390   |     -     |   0.94
# ----------------------------------------------------------------------
#    8    |    -    |   0.741010   |  1.088877  |   47.35
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    8    |  46.943%  |  85.603%  |  56.119%  |     54.258%     |   46.943%    |  70.083%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    8    |  70.083%  |     -     |     -     |     70.083%     |   70.083%    |  70.083%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    9    |   10    |   0.723213   |     -     |   4.84
#    9    |   20    |   0.547902   |     -     |   4.49
#    9    |   30    |   0.580553   |     -     |   6.00
#    9    |   40    |   0.615530   |     -     |   4.02
#    9    |   50    |   0.592638   |     -     |   5.93
#    9    |   52    |   0.617746   |     -     |   0.60
# ----------------------------------------------------------------------
#    9    |    -    |   0.626097   |  1.042692  |   27.92
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    9    |  49.473%  |  87.545%  |  57.560%  |     54.178%     |   49.473%    |  71.395%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    9    |  71.395%  |     -     |     -     |     71.395%     |   71.395%    |  71.395%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   10    |   10    |   0.587769   |     -     |   4.80
#   10    |   20    |   0.502449   |     -     |   4.06
#   10    |   30    |   0.495000   |     -     |   5.54
#   10    |   40    |   0.463200   |     -     |   3.99
#   10    |   50    |   0.426990   |     -     |   5.65
#   10    |   52    |   0.511142   |     -     |   0.57
# ----------------------------------------------------------------------
#   10    |    -    |   0.507002   |  1.033042  |   26.39
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   10    |  47.696%  |  87.849%  |  57.805%  |     54.050%     |   47.696%    |  71.752%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   10    |  71.752%  |     -     |     -     |     71.752%     |   71.752%    |  71.752%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   11    |   10    |   0.472572   |     -     |   4.16
#   11    |   20    |   0.418270   |     -     |   3.71
#   11    |   30    |   0.392360   |     -     |   5.44
#   11    |   40    |   0.426817   |     -     |   3.68
#   11    |   50    |   0.411176   |     -     |   5.47
#   11    |   52    |   0.574782   |     -     |   0.56
# ----------------------------------------------------------------------
#   11    |    -    |   0.439117   |  1.062488  |   24.84
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   11    |  53.651%  |  88.071%  |  59.153%  |     56.433%     |   53.651%    |  72.706%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   11    |  72.706%  |     -     |     -     |     72.706%     |   72.706%    |  72.706%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   12    |   10    |   0.263549   |     -     |   5.28
#   12    |   20    |   0.356107   |     -     |   4.00
#   12    |   30    |   0.313356   |     -     |   6.12
#   12    |   40    |   0.315164   |     -     |   4.36
#   12    |   50    |   0.294621   |     -     |   5.79
#   12    |   52    |   0.319748   |     -     |   0.60
# ----------------------------------------------------------------------
#   12    |    -    |   0.314058   |  1.052552  |   28.09
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   12    |  55.320%  |  86.535%  |  59.281%  |     59.624%     |   55.320%    |  74.851%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   12    |  74.851%  |     -     |     -     |     74.851%     |   74.851%    |  74.851%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   13    |   10    |   0.257675   |     -     |   5.95
#   13    |   20    |   0.265037   |     -     |   6.83
#   13    |   30    |   0.288319   |     -     |   9.92
#   13    |   40    |   0.235779   |     -     |   7.00
#   13    |   50    |   0.265905   |     -     |   10.64
#   13    |   52    |   0.233945   |     -     |   1.08
# ----------------------------------------------------------------------
#   13    |    -    |   0.266398   |  0.997711  |   45.15
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   13    |  55.944%  |  87.820%  |  59.686%  |     56.233%     |   55.944%    |  75.328%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   13    |  75.328%  |     -     |     -     |     75.328%     |   75.328%    |  75.328%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   14    |   10    |   0.178252   |     -     |   7.72
#   14    |   20    |   0.245896   |     -     |   6.53
#   14    |   30    |   0.190296   |     -     |   9.82
#   14    |   40    |   0.184019   |     -     |   5.89
#   14    |   50    |   0.193732   |     -     |   7.77
#   14    |   52    |   0.209799   |     -     |   0.72
# ----------------------------------------------------------------------
#   14    |    -    |   0.202304   |  1.201497  |   41.07
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   14    |  52.064%  |  86.879%  |  59.449%  |     59.265%     |   52.064%    |  72.586%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   14    |  72.586%  |     -     |     -     |     72.586%     |   72.586%    |  72.586%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   15    |   10    |   0.147326   |     -     |   5.75
#   15    |   20    |   0.152731   |     -     |   5.41
#   15    |   30    |   0.192812   |     -     |   8.09
#   15    |   40    |   0.186647   |     -     |   4.84
#   15    |   50    |   0.186480   |     -     |   8.09
#   15    |   52    |   0.203242   |     -     |   0.77
# ----------------------------------------------------------------------
#   15    |    -    |   0.177188   |  1.071341  |   35.74
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   15    |  57.451%  |  87.947%  |  60.401%  |     57.453%     |   57.451%    |  75.566%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   15    |  75.566%  |     -     |     -     |     75.566%     |   75.566%    |  75.566%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   16    |   10    |   0.150212   |     -     |   5.97
#   16    |   20    |   0.144794   |     -     |   5.84
#   16    |   30    |   0.131584   |     -     |   8.37
#   16    |   40    |   0.155865   |     -     |   5.20
#   16    |   50    |   0.125209   |     -     |   8.39
#   16    |   52    |   0.054652   |     -     |   0.75
# ----------------------------------------------------------------------
#   16    |    -    |   0.141080   |  1.092981  |   38.08
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   16    |  56.583%  |  87.179%  |  60.433%  |     57.860%     |   56.583%    |  74.613%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   16    |  74.613%  |     -     |     -     |     74.613%     |   74.613%    |  74.613%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   17    |   10    |   0.150985   |     -     |   6.34
#   17    |   20    |   0.104783   |     -     |   5.60
#   17    |   30    |   0.118285   |     -     |   7.77
#   17    |   40    |   0.120310   |     -     |   5.15
#   17    |   50    |   0.123800   |     -     |   8.33
#   17    |   52    |   0.073324   |     -     |   0.84
# Epoch    17: reducing learning rate of group 0 to 3.0000e-04.
# ----------------------------------------------------------------------
#   17    |    -    |   0.124601   |  1.142072  |   36.89
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   17    |  57.160%  |  87.465%  |  60.472%  |     59.371%     |   57.160%    |  75.089%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   17    |  75.089%  |     -     |     -     |     75.089%     |   75.089%    |  75.089%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   18    |   10    |   0.095112   |     -     |   5.86
#   18    |   20    |   0.100857   |     -     |   5.52
#   18    |   30    |   0.096718   |     -     |   7.67
#   18    |   40    |   0.086729   |     -     |   5.04
#   18    |   50    |   0.076362   |     -     |   7.72
#   18    |   52    |   0.108402   |     -     |   0.80
# ----------------------------------------------------------------------
#   18    |    -    |   0.093648   |  1.118304  |   35.33
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   18    |  56.194%  |  87.753%  |  60.201%  |     57.752%     |   56.194%    |  75.089%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   18    |  75.089%  |     -     |     -     |     75.089%     |   75.089%    |  75.089%
