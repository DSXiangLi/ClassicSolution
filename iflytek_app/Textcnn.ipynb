# %%
import torch
import time 
from sklearn.model_selection import KFold

import torch.nn as nn
from torch.utils.data.sampler import SequentialSampler, RandomSampler
from torch.utils.data.dataloader import DataLoader
from torch.utils.tensorboard import SummaryWriter
from gensim.models.phrases import Phrases
from gensim.models import Word2Vec

from src.train_utils import set_seed, ModelSave, get_torch_device, EarlyStop, TrainParams
from src.evaluation import classification_inference
from src.metric import  multi_cls_metrics,multi_cls_log
from src.dataset.tokenizer import GensimTokenizer

from iflytek_app.dataset import MixDataset
from iflytek_app.models import Textcnn
from iflytek_app.process import train_process, test_process, result_process

device = get_torch_device()
set_seed()
# Out:
# No GPU available, using the CPU instead.

# %%
c2v = GensimTokenizer( Word2Vec.load('./checkpoint/char_min1_win5_sg_d100'))
w2v = GensimTokenizer(Word2Vec.load('./checkpoint/phrase_min1_win5_sg_d100'))
w2v.init_vocab()
c2v.init_vocab()
phraser = Phrases.load('./checkpoint/phrase_tokenizer')
df, label2idx = train_process()
# Out:
#                 id           l1           l2          len
# count  4199.000000  4199.000000  4199.000000  4199.000000
# mean   2099.000000     8.969278    37.087878    46.057156
# std    1212.291219     4.576621    79.204914    79.332999
# min       0.000000     2.000000     1.000000     4.000000
# 25%    1049.500000     5.000000     6.000000    15.000000
# 50%    2099.000000     8.000000    12.000000    22.000000
# 75%    3148.500000    12.000000    26.000000    36.000000
# max    4198.000000    32.000000   946.000000   961.000000
# {'14784131 14858934 14784131 14845064': 0, '14852788 14717848 15639958 15632020': 1, '14844856 14724258 14925237 14854807': 2, '14925756 15639967 14853254 14728639': 3, '14844593 14924945': 4, '15709098 14716590 14924703 14779559': 5, '14726332 14728344 14854542 14844591': 6, '14858934 15636660 15704193 14849963': 7, '15710359 14847407 14845602 14859696': 8, '14794687 14782344': 9, '15630486 15702410 14718849 15709093': 10, '15632285 15706536 14721977 14925219': 11, '14782903 15634620 15638402 15706300': 12, '14844093 15705739 14854331 15699885': 13, '14856354 14844592': 14, '14847385 14844587 14848641 14847398': 15, '14783134 15697333 14854817 14925479': 16, '14924216 14781104 14717848 14791612': 17, '14786237 15697082 14722731 14924977': 18}

# %% [markdown]
# ## Train 5-Fold Model

# %%
log_steps = 10
save_steps = 20
tp = TrainParams(
    epoch_size=30,
    lr=1e-3,
    loss_fn=nn.CrossEntropyLoss(),
    max_seq_len=1000,
    batch_size=64,
    dropout_rate=0.5,
    label_size = len(label2idx),
    vocab_size = w2v.vocab_size,
    embedding_dim = w2v.embedding_size + c2v.embedding_size,
    embedding1=c2v.embedding, 
    embedding2 =w2v.embedding,
    num_train_steps=int(df.shape[0]/5 *4), 
    filter_size=70,
    kernel_size_list = [2,3,4,5],
    hidden_size = 100,
    early_stop_params = {
        'monitor':'f1_micro',
        'mode':'max',
        'min_delta': 0,
        'patience':3,
        'verbose':False
    },
    scheduler_params={'mode': 'max',
                     'factor': 0.3,
                     'patience': 1,
                     'verbose': True,
                     'threshold':0.0001,
                     'threshold_mode':'rel',
                     'cooldown':0,
                     'min_lr':1e-6}
)

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=24)
for fold,(train_index, valid_index) in enumerate(kf.split(df)):
    train, valid = df.iloc[train_index], df.iloc[valid_index]

    train_dataset = MixDataset(tp.max_seq_len, w2v, c2v, phraser, label2idx, 
                               train['name'].values, train['description'].values, train['label'].values)
    valid_dataset = MixDataset(tp.max_seq_len, w2v, c2v, phraser, label2idx, 
                               valid['name'].values, valid['description'].values, valid['label'].values)
    train_sampler = RandomSampler(train_dataset)
    valid_sampler = SequentialSampler(valid_dataset)
    train_loader = DataLoader(train_dataset, sampler=train_sampler, batch_size=tp.batch_size)
    valid_loader = DataLoader(valid_dataset, sampler=valid_sampler, batch_size=tp.batch_size)
    
    CKPT = './checkpoint/textcnn/k{}'.format(fold)
    saver = ModelSave(CKPT, continue_train=False)
    es = EarlyStop(**tp.early_stop_params)
    global_step = 0
    saver.init()
    tb = SummaryWriter(CKPT)
    model = Textcnn(tp)
    optimizer, scheduler = model.get_optimizer()
    
    
    for epoch_i in range(tp['epoch_size']):
        if global_step==1:
            print(model)
        print(f"{'Epoch':^7} | {'Batch':^7} | {'Train Loss':^12} | {'Val Loss':^10}  | {'Elapsed':^9}")
        print("-"*60)

        # Measure the elapsed time of each epoch
        t0_epoch, t0_batch = time.time(), time.time()
        total_loss, batch_loss, batch_counts = 0, 0, 0

        model.train()
        for step, batch in enumerate(train_loader):
            global_step +=1
            batch_counts +=1

            #Forward propogate
            model.zero_grad()
            feature = {k:v.to(device) for k, v in batch.items()}
            logits = model(feature)
            loss = model.compute_loss(feature, logits)
            batch_loss += loss.item()
            total_loss += loss.item()
            loss.backward()
            
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            optimizer.step()

            # Log steps for train loss logging
            if (step % log_steps == 0 and step != 0) or (step == len(train_loader) - 1):
                time_elapsed = time.time() - t0_batch
                print(f"{epoch_i + 1:^7} | {step:^7} | {batch_loss / batch_counts:^12.6f} | {'-':^9} | {time_elapsed:^9.2f}")
                tb.add_scalar('loss/batch_train', batch_loss / batch_counts, global_step=global_step)
                batch_loss, batch_counts = 0, 0
                t0_batch = time.time()

            # Save steps for ckpt saving and dev evaluation
            if (step % save_steps == 0 and step != 0) or (step == len(train_loader) - 1):
                val_metrics = multi_cls_metrics(model, valid_loader, device)
                for key, val in val_metrics.items():
                    tb.add_scalar(f'metric/{key}', val, global_step=global_step)
                avg_train_loss = total_loss / step
                tb.add_scalars('loss/train_valid',{'train': avg_train_loss,
                                                    'valid': val_metrics['val_loss']}, global_step=global_step)
                saver(total_loss / step, val_metrics['val_loss'], epoch_i, global_step, model, optimizer, scheduler)

        # On Epoch End: calcualte train & valid loss and log overall metrics
        time_elapsed = time.time() - t0_epoch
        val_metrics = multi_cls_metrics(model, valid_loader, device)
        avg_train_loss = total_loss / step
        scheduler.step(val_metrics['f1_micro'])
        print("-"*70)
        print(f"{epoch_i + 1:^7} | {'-':^7} | {avg_train_loss:^12.6f} | {val_metrics['val_loss']:^10.6f} | {time_elapsed:^9.2f}")
        multi_cls_log(epoch_i, val_metrics)
        print("\n")
        if es.check(val_metrics):
            break
# Out:
# ./checkpoint/textcnn/k0 model cleaned
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    1    |   10    |   3.680274   |     -     |   7.74
#    1    |   20    |   2.340497   |     -     |   7.69
# C:\Users\86188\.conda\envs\py36_tf23\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: Metric `AUROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# C:\Users\86188\.conda\envs\py36_tf23\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: Metric `AveragePrecision` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# C:\Users\86188\.conda\envs\py36_tf23\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\86188\.conda\envs\py36_tf23\lib\site-packages\torchmetrics\functional\classification\average_precision.py:168: UserWarning: Average precision score for one or more classes was `nan`. Ignoring these classes in average
#   UserWarning,
#    1    |   30    |   2.658483   |     -     |   10.45
#    1    |   40    |   2.354419   |     -     |   6.86
#    1    |   50    |   2.194548   |     -     |   10.42
#    1    |   52    |   2.043952   |     -     |   1.08
# ----------------------------------------------------------------------
#    1    |    -    |   2.693277   |  2.050832  |   47.51
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    1    |  20.785%  |  74.853%  |  27.918%  |     19.512%     |   20.785%    |  45.119%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    1    |  45.119%  |     -     |     -     |     45.119%     |   45.119%    |  45.119%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    2    |   10    |   3.112948   |     -     |   7.69
#    2    |   20    |   1.775467   |     -     |   7.13
#    2    |   30    |   1.837050   |     -     |   10.95
#    2    |   40    |   1.593815   |     -     |   7.11
#    2    |   50    |   1.630007   |     -     |   10.61
#    2    |   52    |   1.230406   |     -     |   1.05
# ----------------------------------------------------------------------
#    2    |    -    |   2.020512   |  1.534089  |   48.09
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    2    |  33.049%  |  80.843%  |  39.629%  |     32.444%     |   33.049%    |  52.619%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    2    |  52.619%  |     -     |     -     |     52.619%     |   52.619%    |  52.619%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    3    |   10    |   1.585096   |     -     |   8.21
#    3    |   20    |   1.538356   |     -     |   7.55
#    3    |   30    |   1.269895   |     -     |   11.52
#    3    |   40    |   1.224081   |     -     |   7.42
#    3    |   50    |   1.161883   |     -     |   11.86
#    3    |   52    |   1.250829   |     -     |   1.21
# ----------------------------------------------------------------------
#    3    |    -    |   1.382305   |  1.289004  |   52.07
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    3    |  41.614%  |  85.587%  |  49.748%  |     40.747%     |   41.614%    |  61.310%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    3    |  61.310%  |     -     |     -     |     61.310%     |   61.310%    |  61.310%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    4    |   10    |   1.116173   |     -     |   13.60
#    4    |   20    |   1.126680   |     -     |   11.87
#    4    |   30    |   0.934387   |     -     |   16.83
#    4    |   40    |   0.873586   |     -     |   11.60
#    4    |   50    |   0.948166   |     -     |   16.69
#    4    |   52    |   0.984666   |     -     |   1.82
# ----------------------------------------------------------------------
#    4    |    -    |   1.020681   |  1.154334  |   77.81
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    4    |  48.307%  |  87.565%  |  54.781%  |     50.407%     |   48.307%    |  65.476%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    4    |  65.476%  |     -     |     -     |     65.476%     |   65.476%    |  65.476%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    5    |   10    |   0.869599   |     -     |   13.26
#    5    |   20    |   0.885439   |     -     |   11.99
#    5    |   30    |   0.641468   |     -     |   16.68
#    5    |   40    |   0.746274   |     -     |   7.24
#    5    |   50    |   0.703202   |     -     |   9.78
#    5    |   52    |   1.119364   |     -     |   1.00
# ----------------------------------------------------------------------
#    5    |    -    |   0.799387   |  1.077426  |   63.02
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    5    |  51.954%  |  88.788%  |  59.796%  |     61.742%     |   51.954%    |  70.357%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    5    |  70.357%  |     -     |     -     |     70.357%     |   70.357%    |  70.357%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    6    |   10    |   0.647722   |     -     |   7.56
#    6    |   20    |   0.635031   |     -     |   6.83
#    6    |   30    |   0.520627   |     -     |   9.77
#    6    |   40    |   0.490562   |     -     |   6.72
#    6    |   50    |   0.558672   |     -     |   9.73
#    6    |   52    |   0.383262   |     -     |   1.00
# ----------------------------------------------------------------------
#    6    |    -    |   0.575777   |  1.024935  |   44.63
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    6    |  52.507%  |  89.707%  |  60.045%  |     59.555%     |   52.507%    |  71.667%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    6    |  71.667%  |     -     |     -     |     71.667%     |   71.667%    |  71.667%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    7    |   10    |   0.520670   |     -     |   8.43
#    7    |   20    |   0.531447   |     -     |   8.47
#    7    |   30    |   0.368087   |     -     |   11.79
#    7    |   40    |   0.384482   |     -     |   6.92
#    7    |   50    |   0.447781   |     -     |   9.83
#    7    |   52    |   0.391266   |     -     |   1.00
# ----------------------------------------------------------------------
#    7    |    -    |   0.458228   |  1.076641  |   49.48
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    7    |  54.719%  |  90.001%  |  61.722%  |     64.792%     |   54.719%    |  71.310%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    7    |  71.310%  |     -     |     -     |     71.310%     |   71.310%    |  71.310%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    8    |   10    |   0.439743   |     -     |   8.83
#    8    |   20    |   0.471157   |     -     |   7.42
#    8    |   30    |   0.302192   |     -     |   10.80
#    8    |   40    |   0.241286   |     -     |   7.34
#    8    |   50    |   0.284788   |     -     |   14.49
#    8    |   52    |   0.237410   |     -     |   1.69
# Epoch     8: reducing learning rate of group 0 to 3.0000e-04.
# ----------------------------------------------------------------------
#    8    |    -    |   0.352043   |  1.159410  |   55.56
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    8    |  54.823%  |  89.419%  |  60.644%  |     68.050%     |   54.823%    |  71.429%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    8    |  71.429%  |     -     |     -     |     71.429%     |   71.429%    |  71.429%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    9    |   10    |   0.353457   |     -     |   12.47
#    9    |   20    |   0.325020   |     -     |   11.18
#    9    |   30    |   0.160770   |     -     |   16.75
#    9    |   40    |   0.154682   |     -     |   11.79
#    9    |   50    |   0.142319   |     -     |   16.87
#    9    |   52    |   0.091085   |     -     |   1.81
# ----------------------------------------------------------------------
#    9    |    -    |   0.228810   |  1.078423  |   76.14
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    9    |  55.668%  |  89.996%  |  62.265%  |     63.700%     |   55.668%    |  73.095%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    9    |  73.095%  |     -     |     -     |     73.095%     |   73.095%    |  73.095%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   10    |   10    |   0.229148   |     -     |   11.87
#   10    |   20    |   0.296846   |     -     |   6.87
#   10    |   30    |   0.128253   |     -     |   9.96
#   10    |   40    |   0.156990   |     -     |   6.92
#   10    |   50    |   0.116623   |     -     |   9.86
#   10    |   52    |   0.097220   |     -     |   1.00
# ----------------------------------------------------------------------
#   10    |    -    |   0.186580   |  1.093841  |   49.61
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   10    |  56.075%  |  89.980%  |  62.103%  |     63.601%     |   56.075%    |  73.571%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   10    |  73.571%  |     -     |     -     |     73.571%     |   73.571%    |  73.571%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   11    |   10    |   0.260707   |     -     |   7.60
#   11    |   20    |   0.215175   |     -     |   6.87
#   11    |   30    |   0.103301   |     -     |   9.92
#   11    |   40    |   0.122170   |     -     |   6.89
#   11    |   50    |   0.101124   |     -     |   9.82
#   11    |   52    |   0.092198   |     -     |   1.03
# ----------------------------------------------------------------------
#   11    |    -    |   0.162882   |  1.123813  |   45.25
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   11    |  56.562%  |  89.875%  |  61.846%  |     62.717%     |   56.562%    |  73.214%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   11    |  73.214%  |     -     |     -     |     73.214%     |   73.214%    |  73.214%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   12    |   10    |   0.224455   |     -     |   7.49
#   12    |   20    |   0.250761   |     -     |   6.92
#   12    |   30    |   0.090652   |     -     |   9.78
#   12    |   40    |   0.088861   |     -     |   6.73
#   12    |   50    |   0.099650   |     -     |   9.83
#   12    |   52    |   0.066854   |     -     |   1.02
# ----------------------------------------------------------------------
#   12    |    -    |   0.151960   |  1.143443  |   44.97
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   12    |  56.203%  |  90.054%  |  62.425%  |     64.177%     |   56.203%    |  73.690%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   12    |  73.690%  |     -     |     -     |     73.690%     |   73.690%    |  73.690%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   13    |   10    |   0.193021   |     -     |   7.64
#   13    |   20    |   0.261943   |     -     |   7.06
#   13    |   30    |   0.077805   |     -     |   9.78
#   13    |   40    |   0.086891   |     -     |   6.81
#   13    |   50    |   0.078410   |     -     |   9.79
#   13    |   52    |   0.183382   |     -     |   1.00
# ----------------------------------------------------------------------
#   13    |    -    |   0.145009   |  1.144618  |   45.16
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   13    |  55.414%  |  89.973%  |  61.967%  |     64.183%     |   55.414%    |  72.857%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   13    |  72.857%  |     -     |     -     |     72.857%     |   72.857%    |  72.857%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   14    |   10    |   0.176763   |     -     |   7.50
#   14    |   20    |   0.210823   |     -     |   6.87
#   14    |   30    |   0.070177   |     -     |   9.82
#   14    |   40    |   0.077379   |     -     |   6.74
#   14    |   50    |   0.081671   |     -     |   9.79
#   14    |   52    |   0.045339   |     -     |   1.00
# Epoch    14: reducing learning rate of group 0 to 9.0000e-05.
# ----------------------------------------------------------------------
#   14    |    -    |   0.123761   |  1.177104  |   44.83
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   14    |  55.846%  |  90.123%  |  62.138%  |     64.925%     |   55.846%    |  73.452%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   14    |  73.452%  |     -     |     -     |     73.452%     |   73.452%    |  73.452%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   15    |   10    |   0.167222   |     -     |   7.45
#   15    |   20    |   0.180152   |     -     |   6.87
#   15    |   30    |   0.071983   |     -     |   10.10
#   15    |   40    |   0.045185   |     -     |   6.88
#   15    |   50    |   0.063263   |     -     |   9.81
#   15    |   52    |   0.029614   |     -     |   0.99
# ----------------------------------------------------------------------
#   15    |    -    |   0.105856   |  1.165436  |   45.17
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   15    |  55.382%  |  90.066%  |  61.886%  |     63.913%     |   55.382%    |  73.452%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   15    |  73.452%  |     -     |     -     |     73.452%     |   73.452%    |  73.452%
#
#
#
#
# Warning: [WinError 3] 系统找不到指定的路径。: './checkpoint/textcnn/k1' not exists
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    1    |   10    |   3.987455   |     -     |   7.48
#    1    |   20    |   2.652642   |     -     |   6.80
#    1    |   30    |   2.620985   |     -     |   9.84
#    1    |   40    |   2.357014   |     -     |   6.79
#    1    |   50    |   2.239123   |     -     |   9.86
#    1    |   52    |   2.133878   |     -     |   1.01
# ----------------------------------------------------------------------
#    1    |    -    |   2.823604   |  2.055621  |   44.85
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    1    |  20.286%  |  68.164%  |  28.459%  |     21.678%     |   20.286%    |  41.786%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    1    |  41.786%  |     -     |     -     |     41.786%     |   41.786%    |  41.786%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    2    |   10    |   2.888688   |     -     |   7.55
#    2    |   20    |   1.994616   |     -     |   6.86
#    2    |   30    |   1.860943   |     -     |   9.81
#    2    |   40    |   1.622782   |     -     |   6.72
#    2    |   50    |   1.621680   |     -     |   9.87
#    2    |   52    |   1.466525   |     -     |   1.00
# ----------------------------------------------------------------------
#    2    |    -    |   2.032862   |  1.468825  |   44.95
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    2    |  29.878%  |  76.287%  |  43.247%  |     37.283%     |   29.878%    |  51.905%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    2    |  51.905%  |     -     |     -     |     51.905%     |   51.905%    |  51.905%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    3    |   10    |   1.538904   |     -     |   7.47
#    3    |   20    |   1.501835   |     -     |   6.87
#    3    |   30    |   1.411487   |     -     |   9.86
#    3    |   40    |   1.218635   |     -     |   6.76
#    3    |   50    |   1.190581   |     -     |   9.79
#    3    |   52    |   1.202589   |     -     |   1.02
# ----------------------------------------------------------------------
#    3    |    -    |   1.395356   |  1.237260  |   44.83
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    3    |  48.047%  |  79.612%  |  53.870%  |     52.196%     |   48.047%    |  65.595%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    3    |  65.595%  |     -     |     -     |     65.595%     |   65.595%    |  65.595%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    4    |   10    |   1.091505   |     -     |   7.53
#    4    |   20    |   1.167629   |     -     |   6.83
#    4    |   30    |   0.998545   |     -     |   9.84
#    4    |   40    |   1.008608   |     -     |   6.76
#    4    |   50    |   1.006054   |     -     |   9.86
#    4    |   52    |   1.133029   |     -     |   1.00
# ----------------------------------------------------------------------
#    4    |    -    |   1.078481   |  1.120674  |   44.85
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    4    |  50.838%  |  81.013%  |  59.215%  |     55.979%     |   50.838%    |  66.310%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    4    |  66.310%  |     -     |     -     |     66.310%     |   66.310%    |  66.310%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    5    |   10    |   0.949563   |     -     |   8.46
#    5    |   20    |   0.981671   |     -     |   6.91
#    5    |   30    |   0.741524   |     -     |   9.65
#    5    |   40    |   0.745030   |     -     |   6.70
#    5    |   50    |   0.739314   |     -     |   9.72
#    5    |   52    |   0.800420   |     -     |   0.96
# ----------------------------------------------------------------------
#    5    |    -    |   0.848489   |  1.064678  |   45.42
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    5    |  56.336%  |  81.796%  |  63.436%  |     62.086%     |   56.336%    |  71.548%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    5    |  71.548%  |     -     |     -     |     71.548%     |   71.548%    |  71.548%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    6    |   10    |   0.787921   |     -     |   7.42
#    6    |   20    |   0.806501   |     -     |   6.75
#    6    |   30    |   0.601429   |     -     |   9.68
#    6    |   40    |   0.560461   |     -     |   6.70
#    6    |   50    |   0.606085   |     -     |   9.68
#    6    |   52    |   0.414284   |     -     |   0.97
# ----------------------------------------------------------------------
#    6    |    -    |   0.677701   |  1.027120  |   44.25
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    6    |  56.572%  |  81.979%  |  65.673%  |     64.136%     |   56.572%    |  72.143%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    6    |  72.143%  |     -     |     -     |     72.143%     |   72.143%    |  72.143%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    7    |   10    |   0.597861   |     -     |   7.44
#    7    |   20    |   0.671927   |     -     |   6.76
#    7    |   30    |   0.434814   |     -     |   9.68
#    7    |   40    |   0.505535   |     -     |   6.64
#    7    |   50    |   0.377646   |     -     |   9.67
#    7    |   52    |   0.433122   |     -     |   0.99
# ----------------------------------------------------------------------
#    7    |    -    |   0.525806   |  1.082466  |   44.17
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    7    |  61.252%  |  82.576%  |  66.441%  |     63.488%     |   61.252%    |  72.500%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    7    |  72.500%  |     -     |     -     |     72.500%     |   72.500%    |  72.500%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    8    |   10    |   0.515579   |     -     |   7.47
#    8    |   20    |   0.490907   |     -     |   6.75
#    8    |   30    |   0.325854   |     -     |   9.67
#    8    |   40    |   0.383472   |     -     |   6.69
#    8    |   50    |   0.362546   |     -     |   9.65
#    8    |   52    |   0.231126   |     -     |   0.99
# ----------------------------------------------------------------------
#    8    |    -    |   0.418489   |  1.029301  |   44.23
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    8    |  63.392%  |  82.889%  |  68.361%  |     64.269%     |   63.392%    |  75.238%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    8    |  75.238%  |     -     |     -     |     75.238%     |   75.238%    |  75.238%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    9    |   10    |   0.464687   |     -     |   7.44
#    9    |   20    |   0.407982   |     -     |   6.73
#    9    |   30    |   0.249552   |     -     |   9.67
#    9    |   40    |   0.263825   |     -     |   7.63
#    9    |   50    |   0.235173   |     -     |   10.44
#    9    |   52    |   0.256835   |     -     |   1.15
# ----------------------------------------------------------------------
#    9    |    -    |   0.330588   |  1.135926  |   46.36
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    9    |  63.061%  |  83.001%  |  69.276%  |     65.856%     |   63.061%    |  75.119%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    9    |  75.119%  |     -     |     -     |     75.119%     |   75.119%    |  75.119%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   10    |   10    |   0.448630   |     -     |   8.53
#   10    |   20    |   0.397947   |     -     |   11.74
#   10    |   30    |   0.185862   |     -     |   16.71
#   10    |   40    |   0.228758   |     -     |   11.53
#   10    |   50    |   0.187413   |     -     |   16.96
#   10    |   52    |   0.253436   |     -     |   1.72
# Epoch    10: reducing learning rate of group 0 to 3.0000e-04.
# ----------------------------------------------------------------------
#   10    |    -    |   0.296954   |  1.096364  |   72.49
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   10    |  62.110%  |  83.107%  |  69.297%  |     68.043%     |   62.110%    |  74.524%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   10    |  74.524%  |     -     |     -     |     74.524%     |   74.524%    |  74.524%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   11    |   10    |   0.336271   |     -     |   12.72
#   11    |   20    |   0.322000   |     -     |   11.74
#   11    |   30    |   0.109278   |     -     |   16.81
#   11    |   40    |   0.114318   |     -     |   10.75
#   11    |   50    |   0.102866   |     -     |   9.82
#   11    |   52    |   0.139198   |     -     |   1.00
# ----------------------------------------------------------------------
#   11    |    -    |   0.201192   |  1.072913  |   65.88
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   11    |  63.668%  |  83.043%  |  69.883%  |     69.398%     |   63.668%    |  76.071%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   11    |  76.071%  |     -     |     -     |     76.071%     |   76.071%    |  76.071%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   12    |   10    |   0.254567   |     -     |   7.48
#   12    |   20    |   0.295319   |     -     |   6.85
#   12    |   30    |   0.096747   |     -     |   9.77
#   12    |   40    |   0.104077   |     -     |   6.70
#   12    |   50    |   0.069091   |     -     |   9.67
#   12    |   52    |   0.122747   |     -     |   0.99
# ----------------------------------------------------------------------
#   12    |    -    |   0.167270   |  1.079889  |   44.48
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   12    |  64.404%  |  83.070%  |  69.981%  |     68.657%     |   64.404%    |  76.071%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   12    |  76.071%  |     -     |     -     |     76.071%     |   76.071%    |  76.071%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   13    |   10    |   0.221269   |     -     |   7.67
#   13    |   20    |   0.212010   |     -     |   6.77
#   13    |   30    |   0.073872   |     -     |   9.75
#   13    |   40    |   0.077320   |     -     |   6.73
#   13    |   50    |   0.082004   |     -     |   9.77
#   13    |   52    |   0.140195   |     -     |   1.00
# Epoch    13: reducing learning rate of group 0 to 9.0000e-05.
# ----------------------------------------------------------------------
#   13    |    -    |   0.137815   |  1.117744  |   44.71
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   13    |  63.156%  |  82.768%  |  69.731%  |     69.206%     |   63.156%    |  75.595%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   13    |  75.595%  |     -     |     -     |     75.595%     |   75.595%    |  75.595%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   14    |   10    |   0.199427   |     -     |   7.50
#   14    |   20    |   0.191231   |     -     |   6.78
#   14    |   30    |   0.063524   |     -     |   9.63
#   14    |   40    |   0.057625   |     -     |   6.70
#   14    |   50    |   0.057197   |     -     |   9.73
#   14    |   52    |   0.077741   |     -     |   1.00
# ----------------------------------------------------------------------
#   14    |    -    |   0.116249   |  1.126901  |   44.35
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   14    |  64.595%  |  82.790%  |  69.765%  |     68.625%     |   64.595%    |  76.190%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   14    |  76.190%  |     -     |     -     |     76.190%     |   76.190%    |  76.190%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   15    |   10    |   0.189140   |     -     |   7.48
#   15    |   20    |   0.207310   |     -     |   6.81
#   15    |   30    |   0.062552   |     -     |   9.74
#   15    |   40    |   0.051839   |     -     |   6.75
#   15    |   50    |   0.073892   |     -     |   9.68
#   15    |   52    |   0.030130   |     -     |   1.02
# ----------------------------------------------------------------------
#   15    |    -    |   0.117245   |  1.111182  |   44.57
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   15    |  63.544%  |  82.809%  |  69.769%  |     68.609%     |   63.544%    |  75.952%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   15    |  75.952%  |     -     |     -     |     75.952%     |   75.952%    |  75.952%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   16    |   10    |   0.161070   |     -     |   7.47
#   16    |   20    |   0.198936   |     -     |   6.83
#   16    |   30    |   0.072129   |     -     |   9.68
#   16    |   40    |   0.056205   |     -     |   6.72
#   16    |   50    |   0.058533   |     -     |   9.76
#   16    |   52    |   0.051051   |     -     |   1.00
# Epoch    16: reducing learning rate of group 0 to 2.7000e-05.
# ----------------------------------------------------------------------
#   16    |    -    |   0.110229   |  1.109312  |   44.47
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   16    |  63.147%  |  82.860%  |  69.857%  |     68.924%     |   63.147%    |  76.071%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   16    |  76.071%  |     -     |     -     |     76.071%     |   76.071%    |  76.071%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   17    |   10    |   0.202341   |     -     |   7.49
#   17    |   20    |   0.169444   |     -     |   6.80
#   17    |   30    |   0.057686   |     -     |   9.70
#   17    |   40    |   0.054089   |     -     |   6.83
#   17    |   50    |   0.054715   |     -     |   9.79
#   17    |   52    |   0.045223   |     -     |   1.02
# ----------------------------------------------------------------------
#   17    |    -    |   0.109145   |  1.104965  |   44.59
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   17    |  63.263%  |  82.819%  |  69.556%  |     69.295%     |   63.263%    |  75.833%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   17    |  75.833%  |     -     |     -     |     75.833%     |   75.833%    |  75.833%
#
#
#
#
# Warning: [WinError 3] 系统找不到指定的路径。: './checkpoint/textcnn/k2' not exists
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    1    |   10    |   3.555486   |     -     |   7.48
#    1    |   20    |   2.504353   |     -     |   7.83
#    1    |   30    |   2.655711   |     -     |   10.37
#    1    |   40    |   2.389317   |     -     |   8.16
#    1    |   50    |   2.139571   |     -     |   10.49
#    1    |   52    |   1.907676   |     -     |   1.09
# ----------------------------------------------------------------------
#    1    |    -    |   2.688754   |  2.099698  |   48.68
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    1    |  15.766%  |  76.114%  |  30.389%  |     18.385%     |   15.766%    |  38.333%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    1    |  38.333%  |     -     |     -     |     38.333%     |   38.333%    |  38.333%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    2    |   10    |   3.262535   |     -     |   8.62
#    2    |   20    |   1.995633   |     -     |   7.04
#    2    |   30    |   1.828670   |     -     |   10.49
#    2    |   40    |   1.609500   |     -     |   7.21
#    2    |   50    |   1.469609   |     -     |   10.50
#    2    |   52    |   1.430135   |     -     |   1.16
# ----------------------------------------------------------------------
#    2    |    -    |   2.072736   |  1.554545  |   48.17
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    2    |  31.968%  |  81.913%  |  42.481%  |     36.806%     |   31.968%    |  55.595%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    2    |  55.595%  |     -     |     -     |     55.595%     |   55.595%    |  55.595%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    3    |   10    |   1.715139   |     -     |   7.71
#    3    |   20    |   1.422488   |     -     |   7.07
#    3    |   30    |   1.357366   |     -     |   9.89
#    3    |   40    |   1.151021   |     -     |   6.80
#    3    |   50    |   1.132565   |     -     |   9.87
#    3    |   52    |   1.328277   |     -     |   1.02
# ----------------------------------------------------------------------
#    3    |    -    |   1.387644   |  1.272117  |   45.40
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    3    |  43.056%  |  85.588%  |  53.665%  |     56.589%     |   43.056%    |  65.357%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    3    |  65.357%  |     -     |     -     |     65.357%     |   65.357%    |  65.357%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    4    |   10    |   1.194910   |     -     |   7.79
#    4    |   20    |   1.158330   |     -     |   6.95
#    4    |   30    |   0.889542   |     -     |   10.06
#    4    |   40    |   0.988933   |     -     |   7.22
#    4    |   50    |   0.893852   |     -     |   11.06
#    4    |   52    |   0.882446   |     -     |   1.02
# ----------------------------------------------------------------------
#    4    |    -    |   1.042605   |  1.142796  |   47.17
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    4    |  50.892%  |  87.167%  |  60.116%  |     53.827%     |   50.892%    |  69.524%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    4    |  69.524%  |     -     |     -     |     69.524%     |   69.524%    |  69.524%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    5    |   10    |   0.975006   |     -     |   8.21
#    5    |   20    |   0.884696   |     -     |   8.16
#    5    |   30    |   0.718752   |     -     |   10.22
#    5    |   40    |   0.736954   |     -     |   6.88
#    5    |   50    |   0.745543   |     -     |   10.33
#    5    |   52    |   0.800935   |     -     |   1.16
# ----------------------------------------------------------------------
#    5    |    -    |   0.830507   |  1.067913  |   48.35
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    5    |  51.916%  |  87.958%  |  62.858%  |     54.217%     |   51.916%    |  69.643%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    5    |  69.643%  |     -     |     -     |     69.643%     |   69.643%    |  69.643%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    6    |   10    |   0.763075   |     -     |   8.09
#    6    |   20    |   0.704850   |     -     |   6.97
#    6    |   30    |   0.600521   |     -     |   10.45
#    6    |   40    |   0.530963   |     -     |   7.74
#    6    |   50    |   0.607681   |     -     |   10.80
#    6    |   52    |   0.774527   |     -     |   1.00
# ----------------------------------------------------------------------
#    6    |    -    |   0.661212   |  1.047008  |   48.16
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    6    |  51.574%  |  87.449%  |  63.766%  |     57.556%     |   51.574%    |  70.238%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    6    |  70.238%  |     -     |     -     |     70.238%     |   70.238%    |  70.238%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    7    |   10    |   0.613168   |     -     |   7.53
#    7    |   20    |   0.641291   |     -     |   7.30
#    7    |   30    |   0.426635   |     -     |   10.85
#    7    |   40    |   0.428447   |     -     |   7.16
#    7    |   50    |   0.428185   |     -     |   10.14
#    7    |   52    |   0.326431   |     -     |   1.04
# ----------------------------------------------------------------------
#    7    |    -    |   0.512371   |  1.024805  |   47.18
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    7    |  55.909%  |  87.316%  |  64.971%  |     62.808%     |   55.909%    |  72.381%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    7    |  72.381%  |     -     |     -     |     72.381%     |   72.381%    |  72.381%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    8    |   10    |   0.536680   |     -     |   8.19
#    8    |   20    |   0.435985   |     -     |   7.60
#    8    |   30    |   0.324201   |     -     |   10.95
#    8    |   40    |   0.317150   |     -     |   7.38
#    8    |   50    |   0.282035   |     -     |   11.35
#    8    |   52    |   0.395449   |     -     |   1.21
# ----------------------------------------------------------------------
#    8    |    -    |   0.390156   |  1.028471  |   49.95
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    8    |  57.506%  |  89.081%  |  65.652%  |     66.706%     |   57.506%    |  73.214%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    8    |  73.214%  |     -     |     -     |     73.214%     |   73.214%    |  73.214%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    9    |   10    |   0.374654   |     -     |   8.16
#    9    |   20    |   0.407001   |     -     |   7.49
#    9    |   30    |   0.245787   |     -     |   10.91
#    9    |   40    |   0.250491   |     -     |   7.19
#    9    |   50    |   0.236062   |     -     |   11.49
#    9    |   52    |   0.250987   |     -     |   1.11
# ----------------------------------------------------------------------
#    9    |    -    |   0.308011   |  1.062651  |   49.81
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    9    |  57.202%  |  89.200%  |  66.383%  |     67.858%     |   57.202%    |  73.571%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ...
# ------------------------------------------------------------
#    6    |   10    |   0.716566   |     -     |   7.55
#    6    |   20    |   0.726859   |     -     |   6.83
#    6    |   30    |   0.600259   |     -     |   9.76
#    6    |   40    |   0.559945   |     -     |   6.82
#    6    |   50    |   0.589800   |     -     |   10.32
#    6    |   52    |   0.617784   |     -     |   1.08
# ----------------------------------------------------------------------
#    6    |    -    |   0.651662   |  0.992104  |   45.71
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    6    |  52.299%  |  87.989%  |  60.213%  |     63.319%     |   52.299%    |  71.871%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    6    |  71.871%  |     -     |     -     |     71.871%     |   71.871%    |  71.871%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    7    |   10    |   0.640966   |     -     |   9.15
#    7    |   20    |   0.568450   |     -     |   7.53
#    7    |   30    |   0.431053   |     -     |   11.64
#    7    |   40    |   0.375563   |     -     |   7.71
#    7    |   50    |   0.405637   |     -     |   19.63
#    7    |   52    |   0.377199   |     -     |   1.81
# ----------------------------------------------------------------------
#    7    |    -    |   0.492539   |  1.000132  |   62.85
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    7    |  56.103%  |  88.199%  |  61.186%  |     62.042%     |   56.103%    |  72.467%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    7    |  72.467%  |     -     |     -     |     72.467%     |   72.467%    |  72.467%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    8    |   10    |   0.459605   |     -     |   14.10
#    8    |   20    |   0.494324   |     -     |   11.72
#    8    |   30    |   0.360036   |     -     |   16.80
#    8    |   40    |   0.260174   |     -     |   11.55
#    8    |   50    |   0.316709   |     -     |   16.74
#    8    |   52    |   0.199746   |     -     |   1.74
# ----------------------------------------------------------------------
#    8    |    -    |   0.380146   |  1.024697  |   77.95
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    8    |  55.745%  |  88.895%  |  61.404%  |     61.611%     |   55.745%    |  73.421%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    8    |  73.421%  |     -     |     -     |     73.421%     |   73.421%    |  73.421%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#    9    |   10    |   0.483352   |     -     |   12.73
#    9    |   20    |   0.458479   |     -     |   11.77
#    9    |   30    |   0.275047   |     -     |   16.78
#    9    |   40    |   0.217972   |     -     |   11.65
#    9    |   50    |   0.228084   |     -     |   16.62
#    9    |   52    |   0.222312   |     -     |   1.81
# ----------------------------------------------------------------------
#    9    |    -    |   0.337641   |  1.054485  |   76.62
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#    9    |  54.254%  |  88.453%  |  62.417%  |     63.698%     |   54.254%    |  72.467%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#    9    |  72.467%  |     -     |     -     |     72.467%     |   72.467%    |  72.467%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   10    |   10    |   0.442207   |     -     |   13.31
#   10    |   20    |   0.349313   |     -     |   12.51
#   10    |   30    |   0.176040   |     -     |   18.27
#   10    |   40    |   0.160969   |     -     |   12.07
#   10    |   50    |   0.152351   |     -     |   15.40
#   10    |   52    |   0.191278   |     -     |   1.04
# ----------------------------------------------------------------------
#   10    |    -    |   0.262184   |  1.039576  |   75.71
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   10    |  56.640%  |  88.543%  |  63.081%  |     62.048%     |   56.640%    |  73.778%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   10    |  73.778%  |     -     |     -     |     73.778%     |   73.778%    |  73.778%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   11    |   10    |   0.290660   |     -     |   7.99
#   11    |   20    |   0.319156   |     -     |   7.29
#   11    |   30    |   0.149211   |     -     |   10.67
#   11    |   40    |   0.122324   |     -     |   7.38
#   11    |   50    |   0.165952   |     -     |   10.53
#   11    |   52    |   0.110428   |     -     |   1.24
# ----------------------------------------------------------------------
#   11    |    -    |   0.211241   |  1.081315  |   48.12
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   11    |  55.342%  |  88.970%  |  62.121%  |     61.451%     |   55.342%    |  73.421%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   11    |  73.421%  |     -     |     -     |     73.421%     |   73.421%    |  73.421%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   12    |   10    |   0.290245   |     -     |   7.61
#   12    |   20    |   0.266881   |     -     |   6.86
#   12    |   30    |   0.124385   |     -     |   9.73
#   12    |   40    |   0.104839   |     -     |   6.69
#   12    |   50    |   0.116160   |     -     |   9.72
#   12    |   52    |   0.091907   |     -     |   1.02
# Epoch    12: reducing learning rate of group 0 to 3.0000e-04.
# ----------------------------------------------------------------------
#   12    |    -    |   0.182676   |  1.057826  |   44.66
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   12    |  54.528%  |  89.283%  |  62.308%  |     58.339%     |   54.528%    |  72.586%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   12    |  72.586%  |     -     |     -     |     72.586%     |   72.586%    |  72.586%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   13    |   10    |   0.277026   |     -     |   7.42
#   13    |   20    |   0.202927   |     -     |   6.76
#   13    |   30    |   0.063441   |     -     |   9.74
#   13    |   40    |   0.045867   |     -     |   6.75
#   13    |   50    |   0.065118   |     -     |   9.71
#   13    |   52    |   0.037387   |     -     |   1.02
# ----------------------------------------------------------------------
#   13    |    -    |   0.132608   |  1.047301  |   44.52
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   13    |  54.193%  |  88.756%  |  64.001%  |     63.724%     |   54.193%    |  74.374%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   13    |  74.374%  |     -     |     -     |     74.374%     |   74.374%    |  74.374%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   14    |   10    |   0.188053   |     -     |   7.85
#   14    |   20    |   0.162259   |     -     |   6.80
#   14    |   30    |   0.049621   |     -     |   9.70
#   14    |   40    |   0.050777   |     -     |   6.70
#   14    |   50    |   0.037905   |     -     |   9.91
#   14    |   52    |   0.041371   |     -     |   1.01
# ----------------------------------------------------------------------
#   14    |    -    |   0.099172   |  1.061045  |   44.94
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   14    |  56.028%  |  89.025%  |  64.140%  |     62.207%     |   56.028%    |  74.851%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   14    |  74.851%  |     -     |     -     |     74.851%     |   74.851%    |  74.851%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   15    |   10    |   0.150134   |     -     |   7.44
#   15    |   20    |   0.121762   |     -     |   6.83
#   15    |   30    |   0.042051   |     -     |   9.74
#   15    |   40    |   0.039373   |     -     |   6.78
#   15    |   50    |   0.040077   |     -     |   9.70
#   15    |   52    |   0.027091   |     -     |   1.00
# ----------------------------------------------------------------------
#   15    |    -    |   0.079582   |  1.073245  |   44.51
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   15    |  54.356%  |  88.743%  |  64.426%  |     62.355%     |   54.356%    |  74.136%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   15    |  74.136%  |     -     |     -     |     74.136%     |   74.136%    |  74.136%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   16    |   10    |   0.161685   |     -     |   7.49
#   16    |   20    |   0.181496   |     -     |   6.78
#   16    |   30    |   0.039901   |     -     |   9.75
#   16    |   40    |   0.036786   |     -     |   6.81
#   16    |   50    |   0.026787   |     -     |   9.84
#   16    |   52    |   0.034107   |     -     |   1.00
# ----------------------------------------------------------------------
#   16    |    -    |   0.090316   |  1.098156  |   44.68
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   16    |  55.763%  |  88.829%  |  64.097%  |     63.688%     |   55.763%    |  75.209%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   16    |  75.209%  |     -     |     -     |     75.209%     |   75.209%    |  75.209%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   17    |   10    |   0.115841   |     -     |   7.50
#   17    |   20    |   0.128264   |     -     |   6.81
#   17    |   30    |   0.027966   |     -     |   9.76
#   17    |   40    |   0.033498   |     -     |   6.80
#   17    |   50    |   0.025442   |     -     |   9.81
#   17    |   52    |   0.024532   |     -     |   1.00
# ----------------------------------------------------------------------
#   17    |    -    |   0.066827   |  1.101724  |   44.74
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   17    |  56.515%  |  88.997%  |  64.260%  |     64.282%     |   56.515%    |  75.209%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   17    |  75.209%  |     -     |     -     |     75.209%     |   75.209%    |  75.209%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   18    |   10    |   0.121439   |     -     |   7.46
#   18    |   20    |   0.116544   |     -     |   6.81
#   18    |   30    |   0.037622   |     -     |   9.81
#   18    |   40    |   0.036072   |     -     |   6.72
#   18    |   50    |   0.026335   |     -     |   9.74
#   18    |   52    |   0.022512   |     -     |   1.00
# Epoch    18: reducing learning rate of group 0 to 9.0000e-05.
# ----------------------------------------------------------------------
#   18    |    -    |   0.068203   |  1.106625  |   44.51
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   18    |  54.098%  |  88.802%  |  64.354%  |     62.106%     |   54.098%    |  74.255%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   18    |  74.255%  |     -     |     -     |     74.255%     |   74.255%    |  74.255%
#
#
#
#
#  Epoch  |  Batch  |  Train Loss  |  Val Loss   |  Elapsed
# ------------------------------------------------------------
#   19    |   10    |   0.120378   |     -     |   7.53
#   19    |   20    |   0.111061   |     -     |   6.89
#   19    |   30    |   0.024884   |     -     |   9.75
#   19    |   40    |   0.018767   |     -     |   6.69
#   19    |   50    |   0.016819   |     -     |   9.86
#   19    |   52    |   0.012780   |     -     |   1.05
# ----------------------------------------------------------------------
#   19    |    -    |   0.058943   |  1.118641  |   44.87
#
#
#  Epoch  | Macro Acc | Macro AUC | Macro AP  | Macro Precision | Macro Recall | Macro F1
# ------------------------------------------------------------------------------------------
#   19    |  54.280%  |  88.809%  |  64.447%  |     63.894%     |   54.280%    |  74.255%
#  Epoch  | Micro Acc | Micro AUC | Micro AP  | Micro Precision | Micro Recall | Micro F1
# ------------------------------------------------------------------------------------------
#   19    |  74.255%  |     -     |     -     |     74.255%     |   74.255%    |  74.255%

# %% [markdown]
# ## K-Fold Evalutaion

# %%
test = test_process()
test_dataset = MixDataset(tp.max_seq_len, w2v, c2v, phraser, label2idx,  test['name'].values, test['description'].values)
test_sampler = SequentialSampler(test_dataset)
test_loader = DataLoader(test_dataset, sampler=test_sampler, batch_size=tp.batch_size)

# %%
result = kfold_inference(test_loader, tp, Textcnn, './checkpoint/textcnn', 5)
result['pred'] = result['pred_major']
result_process(result, label2idx, 'textcnn_5fold_major.csv')

# %%
result['pred'] = result['pred_avg']
result_process(result, label2idx, 'textcnn_5fold_avg.csv')
